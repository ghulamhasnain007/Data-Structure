# %% [markdown]
# # WebScraping
#
# Web Scraping is a method to extract (or scrape) relevant data/information from the website. It may also be referred to as **web data extraction**. Generally, web scraping has a certain goal in mind (to retrieve a certain piece of information) as opposed to **web crawling** in which all data is gathered.
#
# Some examples may be:
# - Gathering job information from [rozee.pk](https://rozee.pk)
# - Gathering car information from pakwheels.
# - Used in Natural Language Processing (NLP) for extracting relevant data (for learning purposes).

# %% [markdown]
# ## Challenges of WebScraping
# - Web scraping is structure dependent. This means, that based on the structure of the website design, the location to look for the relevant information may be different and so the search process cannot be generalized to all types of websites.
# - The scraper can become outdated if the website is modified and the structure is changed.

# %% [markdown]
# # Methodology
#
# Before we dive into details of Python code and relevant libraries, let us just understand the process of web scraping.
#
# 1. We start by choosing the website we want to scrap.
# 2. We go ahead and download the particular web page (using *requests* library).
# 3. We parse the downloaded web page and parse and store it as an html version (other formats are available too). This way, we can access individual html tags.
# 4. We spend some time understanding the structure of the html file. This way we can identify what information is available, how it is stored and how to access it.
# 5. Finally, once the location is identified, we go ahead and write Python code to access relevant data.
# 6. We can store that data as dataframe (other options are available too) and perform data analysis on it.

# %%
#required libraries
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Getting the Web Page
# In order to get the local copy of the webpage, we use the *requests* library from Python. It has a function `get()` that takes the URL of the webpage and stores it as a *content* attribute.

# %%
#request the content from website
page = requests.get("https://washington.craigslist.org/search/cta")
page
# Out:
# <Response [200]>

# %% [markdown]
# If the `get()` operation is successful, the *status_code* attribute is set to **200**, otherwise it is set to **404** in case the operation is not successful.
#
# Since scraping is basically sending requests to a website for information, too many requests may slowdown their server, therefore, many websites block requests if done by robot (or have some policy in place).

# %%
#see response status
page.status_code
# Out:
# 200

# %% [markdown]
# We can view the content of the website, using *content*

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n    \n\t<meta charset="UTF-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge">\n\t<meta name="viewport" content="width=device-width,initial-scale=1">\n\t<meta property="og:site_name" content="craigslist">\n\t<meta name="twitter:card" content="preview">\n\t<meta property="og:title" content="washington, DC cars &amp; trucks - craigslist">\n\t<meta name="description" content="washington, DC cars &amp; trucks - craigslist">\n\t<meta property="og:description" content="washington, DC cars &amp; trucks - craigslist">\n\t<meta property="og:url" content="https://washingtondc.craigslist.org/search/cta">\n\t<meta name="smartbanner:api" content="true">\n\t<meta name="smartbanner:title" content="the craigslist app">\n\t<meta name="smartbanner:author" content="what&#39;s old is new">\n\t<meta name="smartbanner:icon-apple" content="/images/app_icon.png">\n\t<meta name="smartbanner:icon-google" content="/images/app_icon.png">\n\t<meta name="smartbanner:button" content="view">\n\t<meta name="smartbanner:close-label" content="close">\n\t<meta name="smartbanner:button-url-apple" content="https://apps.apple.com/us/app/craigslist/id1336642410">\n\t<meta name="smartbanner:button-url-google" content="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">\n\t<meta name="smartbanner:enabled-platforms" content="android,ios">\n\t<title>washington, DC cars &amp; trucks - craigslist</title>\n\t<link rel="canonical" href="https://washingtondc.craigslist.org/search/cta">\n\t<link rel="next" href="https://washingtondc.craigslist.org/search/cta?s=120">\n\n\n\n<script type="application/ld+json" id="ld_breadcrumb_data" >\n    {"@context":"https://schema.org","itemListElement":[{"item":{"name":"washingtondc.craigslist.org","@id":"https://washingtondc.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"for sale","@id":"https://washingtondc.craigslist.org/search/sss"},"position":2,"@type":"ListItem"},{"item":{"name":"cars+trucks","@id":"https://washingtondc.craigslist.org/search/cta"},"position":3,"@type":"ListItem"}],"@type":"BreadcrumbList"}\n</script>\n\n\n    <style type="text/css">\n        body {\n            font-family: sans-serif;\n        }\n\n        #no-js,\n        #unsupported-browser {\n            position: fixed;\n            z-index: 10000;\n\n            top: 0;\n            left: 0;\n            right: 0;\n            margin: 0;\n            padding: 0;\n            border: 0;\n            background: transparent;\n        }\n\n        #no-js p,\n        #unsupported-browser p {\n            color: black;\n            background-color: #FA8787;\n            opacity: 0.8;\n            text-align: center;\n            margin: 0;\n            border: 0;\n            padding: 1em;\n        }\n\n        #unsupported-browser {\n            display: none;\n        }\n\n        .unsupported-browser #unsupported-browser {\n            display: block;\n        }\n\n        .no-js header,\n        .no-js form,\n        .no-js .tsb,\n        .unsupported-browser header,\n        .unsupported-browser form,\n        .unsupported-browser .tsb {\n            display: none;\n        }\n\n        #curtain {\n            display: none;\n            position: fixed;\n            z-index: 9000;\n            top: 0;\n            bottom: 0;\n            left: 0;\n            right: 0;\n            margin: 0;\n            padding: 0;\n            border: 0;\n            background: transparent;\n        }\n\n        .show-curtain #curtain {\n            display: block;\n        }\n\n        #curtain .cover,\n        #curtain .content {\n            position: absolute;\n            display: block;\n            top: 0;\n            bottom: 0;\n            left: 0;\n            right: 0;\n            margin: 0;\n            padding: 0;\n            border: 0;\n        }\n\n        #curtain .cover {\n            z-index: 1;\n            background-color: white;\n        }\n\n        .show- ...

# %% [markdown]
# Not a pretty picture, huh.

# %% [markdown]
# # Parsing the Webpage
# Once, we have the local copy of the webpage, the next step is to parse it for scraping purposes. For this purpose, we have a Python library called **Beautiful Soup**.

# %% [markdown]
# ## Beautiful Soup
# The Beautiful Soup library is a Python library used to extract structured data from the webpage. It is a helper module to interact with HTML and allows to parse data from HTML and XML files.
#
# This way, it is more readable than what is acquired by the `requests` library.
#
# There are multiple parsers available (as discussed in the next slide), however for our exercise, we will stick to *html* parser.

# %%
# create beautifulSoup object
soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# ## Different Available parsers
# <table class="docutils align-default">
# <colgroup>
# <col style="width: 18%">
# <col style="width: 35%">
# <col style="width: 26%">
# <col style="width: 21%">
# </colgroup>
# <tbody>
# <tr class="row-odd"><td><p>Parser</p></td>
# <td><p>Typical usage</p></td>
# <td><p>Advantages</p></td>
# <td><p>Disadvantages</p></td>
# </tr>
# <tr class="row-even"><td><p>Python’s html.parser</p></td>
# <td><p><code class="docutils literal notranslate"><span class="pre">BeautifulSoup(markup,</span> <span class="pre">"html.parser")</span></code></p></td>
# <td><ul class="simple">
# <li><p>Batteries included</p></li>
# <li><p>Decent speed</p></li>
# <li><p>Lenient (As of Python 3.2)</p></li>
# </ul>
# </td>
# <td><ul class="simple">
# <li><p>Not as fast as lxml,
# less lenient than
# html5lib.</p></li>
# </ul>
# </td>
# </tr>
# <tr class="row-odd"><td><p>lxml’s HTML parser</p></td>
# <td><p><code class="docutils literal notranslate"><span class="pre">BeautifulSoup(markup,</span> <span class="pre">"lxml")</span></code></p></td>
# <td><ul class="simple">
# <li><p>Very fast</p></li>
# <li><p>Lenient</p></li>
# </ul>
# </td>
# <td><ul class="simple">
# <li><p>External C dependency</p></li>
# </ul>
# </td>
# </tr>
# <tr class="row-even"><td><p>lxml’s XML parser</p></td>
# <td><p><code class="docutils literal notranslate"><span class="pre">BeautifulSoup(markup,</span> <span class="pre">"lxml-xml")</span></code>
# <code class="docutils literal notranslate"><span class="pre">BeautifulSoup(markup,</span> <span class="pre">"xml")</span></code></p></td>
# <td><ul class="simple">
# <li><p>Very fast</p></li>
# <li><p>The only currently supported
# XML parser</p></li>
# </ul>
# </td>
# <td><ul class="simple">
# <li><p>External C dependency</p></li>
# </ul>
# </td>
# </tr>
# <tr class="row-odd"><td><p>html5lib</p></td>
# <td><p><code class="docutils literal notranslate"><span class="pre">BeautifulSoup(markup,</span> <span class="pre">"html5lib")</span></code></p></td>
# <td><ul class="simple">
# <li><p>Extremely lenient</p></li>
# <li><p>Parses pages the same way a
# web browser does</p></li>
# <li><p>Creates valid HTML5</p></li>
# </ul>
# </td>
# <td><ul class="simple">
# <li><p>Very slow</p></li>
# <li><p>External Python
# dependency</p></li>
# </ul>
# </td>
# </tr>
# </tbody>
# </table>
#
# <center><a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-a-parser">Source</a></center>
#
# On more detail on differences between parsers, click [here](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#differences-between-parsers)

# %% [markdown]
# ### `prettify()`
# This is a very important function that prints the html file in a better formatted string with indentation.

# %%
#View formatted content
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="craigslist" property="og:site_name"/>
#   <meta content="preview" name="twitter:card"/>
#   <meta content="washington, DC cars &amp; trucks - craigslist" property="og:title"/>
#   <meta content="washington, DC cars &amp; trucks - craigslist" name="description"/>
#   <meta content="washington, DC cars &amp; trucks - craigslist" property="og:description"/>
#   <meta content="https://washingtondc.craigslist.org/search/cta" property="og:url"/>
#   <meta content="true" name="smartbanner:api"/>
#   <meta content="the craigslist app" name="smartbanner:title"/>
#   <meta content="what's old is new" name="smartbanner:author"/>
#   <meta content="/images/app_icon.png" name="smartbanner:icon-apple"/>
#   <meta content="/images/app_icon.png" name="smartbanner:icon-google"/>
#   <meta content="view" name="smartbanner:button"/>
#   <meta content="close" name="smartbanner:close-label"/>
#   <meta content="https://apps.apple.com/us/app/craigslist/id1336642410" name="smartbanner:button-url-apple"/>
#   <meta content="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile" name="smartbanner:button-url-google"/>
#   <meta content="android,ios" name="smartbanner:enabled-platforms"/>
#   <title>
#    washington, DC cars &amp; trucks - craigslist
#   </title>
#   <link href="https://washingtondc.craigslist.org/search/cta" rel="canonical"/>
#   <link href="https://washingtondc.craigslist.org/search/cta?s=120" rel="next"/>
#   <script id="ld_breadcrumb_data" type="application/ld+json">
#    {"@context":"https://schema.org","itemListElement":[{"item":{"name":"washingtondc.craigslist.org","@id":"https://washingtondc.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"for sale","@id":"https://washingtondc.craigslist.org/search/sss"},"position":2,"@type":"ListItem"},{"item":{"name":"cars+trucks","@id":"https://washingtondc.craigslist.org/search/cta"},"position":3,"@type":"ListItem"}],"@type":"BreadcrumbList"}
#   </script>
#   <style type="text/css">
#    body {
#             font-family: sans-serif;
#         }
#
#         #no-js,
#         #unsupported-browser {
#             position: fixed;
#             z-index: 10000;
#
#             top: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#             background: transparent;
#         }
#
#         #no-js p,
#         #unsupported-browser p {
#             color: black;
#             background-color: #FA8787;
#             opacity: 0.8;
#             text-align: center;
#             margin: 0;
#             border: 0;
#             padding: 1em;
#         }
#
#         #unsupported-browser {
#             display: none;
#         }
#
#         .unsupported-browser #unsupported-browser {
#             display: block;
#         }
#
#         .no-js header,
#         .no-js form,
#         .no-js .tsb,
#         .unsupported-browser header,
#         .unsupported-browser form,
#         .unsupported-browser .tsb {
#             display: none;
#         }
#
#         #curtain {
#             display: none;
#             position: fixed;
#             z-index: 9000;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#             background: transparent;
#         }
#
#         .show-curtain #curtain {
#             display: block;
#         }
#
#         #curtain .cover,
#         #curtain .content {
#             position: absolute;
#             display: block;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#         }
#
#         #curtain .cover {
#             z-index: 1;
#             background-color: white;
#         }
#
#         .show-curtain #curtain .cover {
#             opacity: 0.7;
#         }
#
#         .show-curtain.clear #curtain .cover {
#             opacity: 0;
#         }
#
#         .show-curtain.opaque #curtain .cover {
#             opacity: 1;
#         }
#
#         #curtain .content {
#             z-index: 2;
#             background: transparent;
#             color: #00E;
#
#             display: flex;
#             flex-direction: column;
#             justify-content: center;
#             align-items: center;
#         }
#
#         @keyframes rotate {
#             from {
#                 transform: rotate(0deg);
#             }
#             to {
#                 transform: rotate(359deg);
#             }
#         }
#
#         .pacify #curtain .icom- {
#             font-size: 3em;
#             animation: rotate 2s infinite linear;
#         }
#
#         .pacify #curtain .icom-:after {
#             content: "\eb23";
#         }
#
#         #curtain .text {
#             display: none;
#             font-size: 2em;
#         }
#
#         .loading #curtain .text.loading,
#         .reading #curtain .text.reading,
#         .writing #curtain .text.writing,
#         .saving #curtain .text.saving,
#         .searching #curtain .text.searching,
#         .unrecoverable #curtain .text.unrecoverable,
#         .message #curtain .text.message {
#             display: block;
#         }
#   </style>
#   <script src="https://www.craigslist.org/static/www/4aa05aa5430548804d0c2c9dc3363f638c857c1f.js">
#   </script>
#   <script>
#    window.cl.init(
#              'https://www.craigslist.org/static/www/',
#              '',
#              'www',
#              'browsePostings',
#              {
# areaCountry: "US",
# areaID: "10",
# areaRegion: "DC",
# catAbb: "cta",
# categoryStr: "cta",
# countOfTotalText: "image {count} of {total}",
# currencySymbol: "&#x0024;",
# defaultLocale: "en_US",
# defaultView: "grid",
# expiredFavIDs: null,
# hubLinkText: null,
# hubName: null,
# imageConfig: {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"4":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"3":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}},
# lessInfoText: "less info",
# locParams: null,
# locString: "",
# maptileBaseUrl: "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png",
# maxResults: 3000,
# noImageText: "no image",
# pID: null,
# postalLat: null,
# postalLon: null,
# purveyorCategories: {"owner":"cto","dealer":"ctd","all":"cta"},
# purveyorStr: "",
# searchDistance: null,
# sectionAbb: "sss",
# sectionBase: "sss",
# showInfoText: "show info",
# showMapTabs: 1,
# showingBanished: 0,
# showingFavorites: 0,
# starHint: "save this post in your favorites list",
# subarea: null,
# zoomToPosting: null
# },
#              0
#          );
#   </script>
#  </head>
#  <body class="no-js show-curtain opaque search has-map">
#   <iframe id="cl-local-storage" src="https://www.craigslist.org/static/www/localStorage-092e9f9e2f09450529e744902aa7cdb3a5cc868d.html" style="display:none;">
#   </iframe>
#   <div id="curtain">
#    <div class="cover">
#    </div>
#    <div class="content">
#     <div class="icom-">
#     </div>
#     <div class="text loading">
#      loading
#     </div>
#     <div class="text reading">
#      reading
#     </div>
#     <div class="text writing">
#      writing
#     </div>
#     <div class="text saving">
#      saving
#     </div>
#     <div class="text searching">
#      searching
#     </div>
#     <div class="text unrecoverable">
#      There was an error loading the page; please try to
#      <a href="#" id="cl-unrecoverable-hard-refresh" onclick="location.reload(true);">
#       refresh the page.
#      </a>
#     </div>
#     <div class="text message">
#     </div>
#    </div>
#   </div>
#   <noscript id="no-js">
#    <div>
#     <p>
#      We've detected that JavaScript is not enabled in your browser.
#     </p>
#     <p>
#      You must enable JavaScript to use craigslist.
#     </p>
#    </div>
#   </noscript>
#   <div id="unsupported-browser">
#    <p>
#     We've detected you are using a browser that is missing critical features.
#    </p>
#    <p>
#     Please visit craigslist from a modern browser.
#    </p>
#   </div>
#   <section class="page-container" data-areaid="10" id="page-top">
#    <div class="bglogo">
#    </div>
#    <header class="global-header wide">
#     <a class="header-logo" href="https://washingtondc.craigslist.org" name="logoLink">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <form action="/search/cta" class="breadcrumbs-form" id="breadcrumbform" method="get">
#       <ul class="breadcrumbs">
#        <li class="crumb area">
#         <span class="no-js">
#          <a href="/">
#           washington, DC
#          </a>
#         </span>
#         <select class="js-only" id="areaAbb" name="areaAbb">
#          <option value="washingtondc">
#           washington, DC
#          </option>
#          <option value="allentown">
#           allentown
#          </option>
#          <option value="altoona">
#           altoona
#          </option>
#          <option value="annapolis">
#           annapolis
#          </option>
#          <option value="baltimore">
#           baltimore
#          </option>
#          <option value="binghamton">
#           binghamton
#          </option>
#          <option value="blacksburg">
#           blacksburg
#          </option>
#          <option value="cnj">
#           central NJ
#          </option>
#          <option value="charlottesville">
#           charlottesville
#          </option>
#          <option value="chambersburg">
#           cumberland val
#          </option>
#          <option value="danville">
#           danville
#          </option>
#          <option value="delaware">
#           delaware
#          </option>
#          <option value="eastnc">
#           eastern NC
#          </option>
#          <option value="easternshore">
#           eastern shore
#          </option>
#          <option value="martinsburg">
#           eastern WV
#          </option>
#          <option value="elmira">
#           elmira
#          </option>
#          <option value="frederick">
#           frederick
#          </option>
#          <option value="fredericksburg">
#           fredericksburg
#          </option>
#          <option value="harrisburg">
#           harrisburg
#          </option>
#          <option value="harrisonburg">
#           harrisonburg
#          </option>
#          <option value="jerseyshore">
#           jersey shore
#          </option>
#          <option value="lancaster">
#           lancaster, PA
#          </option>
#          <option value="lynchburg">
#           lynchburg
#          </option>
#          <option value="morgantown">
#           morgantown
#          </option>
#          <option value="newyork">
#           new york
#          </option>
#          <option value="norfolk">
#           norfolk
#          </option>
#          <option value="newjersey">
#           north jersey
#          </option>
#          <option value="wheeling">
#           northern WV
#          </option>
#          <option value="outerbanks">
#           outer banks
#          </option>
#          <option value="philadelphia">
#           philadelphia
#          </option>
#          <option value="pittsburgh">
#           pittsburgh
#          </option>
#          <option value="poconos">
#           poconos
#          </option>
#          <option value="raleigh">
#           raleigh
#          </option>
#          <option value="reading">
#           reading
#          </option>
#          <option value="richmond">
#           richmond, VA
#          </option>
#          <option value="roanoke">
#           roanoke
#          </option>
#          <option value="scranton">
#           scranton
#          </option>
#          <option value="southjersey">
#           south jersey
#          </option>
#          <option value="smd">
#           southern MD
#          </option>
#          <option value="pennstate">
#           state college
#          </option>
#          <option value="twintiers">
#           twin tiers
#          </option>
#          <option value="wv">
#           west virginia
#          </option>
#          <option value="westmd">
#           western MD
#          </option>
#          <option value="williamsport">
#           williamsport
#          </option>
#          <option value="winchester">
#           winchester
#          </option>
#          <option value="york">
#           york, PA
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb subarea">
#         <select id="subArea" name="subArea">
#          <option selected="" value="">
#           all washington, DC
#          </option>
#          <option value="doc">
#           district of columbia
#          </option>
#          <option value="mld">
#           maryland
#          </option>
#          <option value="nva">
#           northern virginia
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb section">
#         <select id="catAbb" name="catAbb">
#          <option value="ccc">
#           community
#          </option>
#          <option value="eee">
#           events
#          </option>
#          <option selected="" value="sss">
#           for sale
#          </option>
#          <option value="ggg">
#           gigs
#          </option>
#          <option value="hhh">
#           housing
#          </option>
#          <option value="jjj">
#           jobs
#          </option>
#          <option value="rrr">
#           resumes
#          </option>
#          <option value="bbb">
#           services
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb category">
#         <select class="js-only" id="subcatAbb">
#          <option value="sss">
#           all
#          </option>
#          <option value="ata">
#           antiques
#          </option>
#          <option value="ppa">
#           appliances
#          </option>
#          <option value="ara">
#           arts+crafts
#          </option>
#          <option value="sna">
#           atvs/utvs/snow
#          </option>
#          <option value="pta">
#           auto parts
#          </option>
#          <option value="wta">
#           auto wheels &amp; tires
#          </option>
#          <option value="ava">
#           aviation
#          </option>
#          <option value="baa">
#           baby+kids
#          </option>
#          <option value="bar">
#           barter
#          </option>
#          <option value="haa">
#           beauty+hlth
#          </option>
#          <option value="bip">
#           bike parts
#          </option>
#          <option value="bia">
#           bikes
#          </option>
#          <option value="bpa">
#           boat parts
#          </option>
#          <option value="boo">
#           boats
#          </option>
#          <option value="bka">
#           books
#          </option>
#          <option value="bfa">
#           business
#          </option>
#          <option selected="" value="cta">
#           cars+trucks
#          </option>
#          <option value="ema">
#           cds/dvd/vhs
#          </option>
#          <option value="moa">
#           cell phones
#          </option>
#          <option value="cla">
#           clothes+acc
#          </option>
#          <option value="cba">
#           collectibles
#          </option>
#          <option value="syp">
#           computer parts
#          </option>
#          <option value="sya">
#           computers
#          </option>
#          <option value="ela">
#           electronics
#          </option>
#          <option value="gra">
#           farm+garden
#          </option>
#          <option value="zip">
#           free stuff
#          </option>
#          <option value="fua">
#           furniture
#          </option>
#          <option value="gms">
#           garage sales
#          </option>
#          <option value="foa">
#           general
#          </option>
#          <option value="hva">
#           heavy equipment
#          </option>
#          <option value="hsa">
#           household
#          </option>
#          <option value="jwa">
#           jewelry
#          </option>
#          <option value="maa">
#           materials
#          </option>
#          <option value="mpa">
#           motorcycle parts
#          </option>
#          <option value="mca">
#           motorcycles
#          </option>
#          <option value="msa">
#           music instr
#          </option>
#          <option value="pha">
#           photo+video
#          </option>
#          <option value="rva">
#           RVs
#          </option>
#          <option value="sga">
#           sporting
#          </option>
#          <option value="tia">
#           tickets
#          </option>
#          <option value="tla">
#           tools
#          </option>
#          <option value="taa">
#           toys+games
#          </option>
#          <option value="tra">
#           trailers
#          </option>
#          <option value="vga">
#           video gaming
#          </option>
#          <option value="waa">
#           wanted
#          </option>
#         </select>
#         <span class="no-js">
#          cars+trucks
#         </span>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#       </ul>
#      </form>
#     </nav>
#     <div class="userlinks">
#      <ul class="user-actions">
#       <li class="user post">
#        <a href="https://post.craigslist.org/c/wdc">
#         post
#        </a>
#       </li>
#       <li class="user account">
#        <a href="https://accounts.craigslist.org/login/home">
#         account
#        </a>
#       </li>
#      </ul>
#      <ul class="user-favs-discards">
#       <li class="user">
#        <div class="favorites">
#         <a class="favlink" href="#">
#          <span aria-hidden="true" class="icon icon-star fav">
#          </span>
#          <span class="fav-number">
#           0
#          </span>
#          <span class="fav-label">
#           favorites
#          </span>
#         </a>
#        </div>
#       </li>
#       <li class="user discards">
#        <div class="to-banish-page">
#         <a class="to-banish-page-link" href="#">
#          <span aria-hidden="true" class="icon icon-trash red">
#          </span>
#          <span class="banished_count">
#           0
#          </span>
#          <span class="discards-label">
#           hidden
#          </span>
#         </a>
#        </div>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <header class="global-header narrow">
#     <a class="header-logo" href="https://washingtondc.craigslist.org">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <h1 class="breadcrumbs">
#       washington, DC            &gt;
#
# cars &amp; trucks
#      </h1>
#     </nav>
#     <span class="linklike show-wide-header">
#      ...
#     </span>
#    </header>
#    <form action="/search/cta" class="search-form" id="searchform">
#     <div class="querybox">
#      <div class="form-tab js-only">
#       <span class="search-open" title="hide search">
#        «
#       </span>
#       <span class="search-closed" title="show search">
#        »
#       </span>
#      </div>
#      <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search cars &amp; trucks" type="text" value=""/>
#      <button class="searchbtn" type="submit">
#       <span aria-hidden="true" class="icon icon-search">
#       </span>
#       <span class="screen-reader-text">
#        press to search craigslist
#       </span>
#      </button>
#      <div class="savealert">
#       <a class="saveme" data-action="save" href="https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Fwashingtondc%2Ecraigslist%2Eorg%2Fsearch%2Fcta" title="save this search">
#        save search
#       </a>
#      </div>
#     </div>
#     <div class="search-options-container">
#      <h1 class="cattitle">
#       <a class="reset" href="https://washingtondc.craigslist.org/search/cta" title="clear all search parameters">
#        cars &amp; trucks
#       </a>
#      </h1>
#      <div class="search-options-header linklike">
#       <div aria-hidden="true" class="icon icon-toggle-gear">
#       </div>
#       options
#       <span class="options-close">
#        close
#       </span>
#      </div>
#      <input id="excats" name="excats" type="hidden"/>
#      <div class="search-options">
#       <div class="searchgroup categories">
#       </div>
#       <input name="userid" type="hidden" value="">
#        <div id="purveyor">
#         <ul class="searchgroup buttongroup purveyor">
#          <li class="button sel">
#           <a data-val="all" href="/search/cta" id="all-purveyor">
#            all
#           </a>
#          </li>
#          <li class="button">
#           <a data-val="owner" href="/search/cta?purveyor=owner" id="owner-purveyor">
#            owner
#           </a>
#          </li>
#          <li class="button">
#           <a data-val="dealer" href="/search/cta?purveyor=dealer" id="dealer-purveyor">
#            dealer
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="searchgroup" id="basic-bools">
#         <ul>
#          <li>
#           <label class="srchType">
#            <input class="" name="srchType" type="checkbox" value="T"/>
#            search titles only
#           </label>
#          </li>
#          <li>
#           <label class="hasPic">
#            <input class="autosubmit" name="hasPic" type="checkbox" value="1"/>
#            has image
#           </label>
#          </li>
#          <li>
#           <label class="postedToday">
#            <input class="autosubmit" name="postedToday" type="checkbox" value="1"/>
#            posted today
#           </label>
#          </li>
#          <li>
#           <label class="bundleDuplicates">
#            <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1"/>
#            bundle duplicates
#           </label>
#          </li>
#          <li>
#           <label class="searchNearby">
#            <input class="autosubmit" name="searchNearby" type="checkbox" value="1"/>
#            include nearby areas
#           </label>
#          </li>
#         </ul>
#         <ul class="js-only nearbyAreas">
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_64" name="nearbyArea" type="checkbox" value="251">
#             akron / canton
#             <small>
#              (cak)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_20" name="nearbyArea" type="checkbox" value="355">
#             altoona-johnstown
#             <small>
#              (aoo)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_1" name="nearbyArea" type="checkbox" value="460">
#             annapolis, MD
#             <small>
#              (anp)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_11">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_66" name="nearbyArea" type="checkbox" value="700">
#             ashtabula, OH
#             <small>
#              (jfn)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_60" name="nearbyArea" type="checkbox" value="438">
#             athens, OH
#             <small>
#              (ohu)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_2" name="nearbyArea" type="checkbox" value="34">
#             baltimore, MD
#             <small>
#              (bal)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_43" name="nearbyArea" type="checkbox" value="248"/>
#            binghamton, NY
#            <small>
#             (bgm)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_11">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_70" name="nearbyArea" type="checkbox" value="40"/>
#            buffalo, NY
#            <small>
#             (buf)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_55" name="nearbyArea" type="checkbox" value="451"/>
#            catskills
#            <small>
#             (cat)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_25" name="nearbyArea" type="checkbox" value="349"/>
#            central NJ
#            <small>
#             (cnj)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_52" name="nearbyArea" type="checkbox" value="439"/>
#            charleston, WV
#            <small>
#             (crw)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_14" name="nearbyArea" type="checkbox" value="290"/>
#            charlottesville, VA
#            <small>
#             (uva)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_58" name="nearbyArea" type="checkbox" value="452"/>
#            chautauqua, NY
#            <small>
#             (chq)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_12">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_74" name="nearbyArea" type="checkbox" value="27"/>
#            cleveland, OH
#            <small>
#             (cle)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_9" name="nearbyArea" type="checkbox" value="705"/>
#            cumberland valley
#            <small>
#             (cbg)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_35" name="nearbyArea" type="checkbox" value="367"/>
#            danville
#            <small>
#             (dnv)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_10" name="nearbyArea" type="checkbox" value="193"/>
#            delaware
#            <small>
#             (dlw)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_12">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_77" name="nearbyArea" type="checkbox" value="281"/>
#            eastern CT
#            <small>
#             (nlo)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_42" name="nearbyArea" type="checkbox" value="335"/>
#            eastern NC
#            <small>
#             (enc)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_6" name="nearbyArea" type="checkbox" value="444"/>
#            eastern panhandle
#            <small>
#             (ewv)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_5" name="nearbyArea" type="checkbox" value="328"/>
#            eastern shore
#            <small>
#             (esh)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_40" name="nearbyArea" type="checkbox" value="453"/>
#            elmira-corning
#            <small>
#             (elm)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_62" name="nearbyArea" type="checkbox" value="275"/>
#            erie, PA
#            <small>
#             (eri)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_65" name="nearbyArea" type="checkbox" value="273"/>
#            fayetteville, NC
#            <small>
#             (fay)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_51" name="nearbyArea" type="checkbox" value="685"/>
#            finger lakes, NY
#            <small>
#             (fgl)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_3" name="nearbyArea" type="checkbox" value="633"/>
#            frederick, MD
#            <small>
#             (fdk)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_4" name="nearbyArea" type="checkbox" value="457"/>
#            fredericksburg, VA
#            <small>
#             (ezf)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_49" name="nearbyArea" type="checkbox" value="61"/>
#            greensboro, NC
#            <small>
#             (gbo)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_12" name="nearbyArea" type="checkbox" value="166"/>
#            harrisburg, PA
#            <small>
#             (hrs)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_15" name="nearbyArea" type="checkbox" value="447"/>
#            harrisonburg, VA
#            <small>
#             (shd)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_12">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_73" name="nearbyArea" type="checkbox" value="44"/>
#            hartford, CT
#            <small>
#             (htf)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_54" name="nearbyArea" type="checkbox" value="249"/>
#            hudson valley, NY
#            <small>
#             (hud)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_11">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_71" name="nearbyArea" type="checkbox" value="442"/>
#            huntington-ashland
#            <small>
#             (hts)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_50" name="nearbyArea" type="checkbox" value="201"/>
#            ithaca, NY
#            <small>
#             (ith)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_11">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_67" name="nearbyArea" type="checkbox" value="634"/>
#            jacksonville, NC
#            <small>
#             (oaj)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_28" name="nearbyArea" type="checkbox" value="561"/>
#            jersey shore
#            <small>
#             (jys)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_11" name="nearbyArea" type="checkbox" value="279"/>
#            lancaster, PA
#            <small>
#             (lns)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_22" name="nearbyArea" type="checkbox" value="167"/>
#            lehigh valley
#            <small>
#             (alt)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_48" name="nearbyArea" type="checkbox" value="250"/>
#            long island, NY
#            <small>
#             (isp)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_24" name="nearbyArea" type="checkbox" value="366"/>
#            lynchburg, VA
#            <small>
#             (lyn)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_53" name="nearbyArea" type="checkbox" value="706"/>
#            meadville, PA
#            <small>
#             (mdv)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_27" name="nearbyArea" type="checkbox" value="440"/>
#            morgantown, WV
#            <small>
#             (wvu)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_61" name="nearbyArea" type="checkbox" value="168"/>
#            new haven, CT
#            <small>
#             (hvn)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_39" name="nearbyArea" type="checkbox" value="291"/>
#            new river valley
#            <small>
#             (vpi)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_34" name="nearbyArea" type="checkbox" value="3"/>
#            new york city
#            <small>
#             (nyc)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_23" name="nearbyArea" type="checkbox" value="48"/>
#            norfolk / hampton roads
#            <small>
#             (nfk)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_36" name="nearbyArea" type="checkbox" value="170"/>
#            north jersey
#            <small>
#             (njy)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_38" name="nearbyArea" type="checkbox" value="443"/>
#            northern panhandle
#            <small>
#             (whl)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_11">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_68" name="nearbyArea" type="checkbox" value="354"/>
#            northwest CT
#            <small>
#             (nct)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_59" name="nearbyArea" type="checkbox" value="684"/>
#            oneonta, NY
#            <small>
#             (onh)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_37" name="nearbyArea" type="checkbox" value="336"/>
#            outer banks
#            <small>
#             (obx)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_46" name="nearbyArea" type="checkbox" value="441"/>
#            parkersburg-marietta
#            <small>
#             (pkb)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_19" name="nearbyArea" type="checkbox" value="17"/>
#            philadelphia
#            <small>
#             (phi)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_31" name="nearbyArea" type="checkbox" value="33"/>
#            pittsburgh, PA
#            <small>
#             (pit)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_29" name="nearbyArea" type="checkbox" value="356"/>
#            poconos
#            <small>
#             (poc)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_44" name="nearbyArea" type="checkbox" value="36"/>
#            raleigh / durham / CH
#            <small>
#             (ral)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_18" name="nearbyArea" type="checkbox" value="278"/>
#            reading, PA
#            <small>
#             (rea)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_13" name="nearbyArea" type="checkbox" value="60"/>
#            richmond, VA
#            <small>
#             (ric)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_32" name="nearbyArea" type="checkbox" value="289"/>
#            roanoke, VA
#            <small>
#             (roa)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_12">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_72" name="nearbyArea" type="checkbox" value="126"/>
#            rochester, NY
#            <small>
#             (rcs)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_30" name="nearbyArea" type="checkbox" value="276"/>
#            scranton / wilkes-barre
#            <small>
#             (avp)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_17" name="nearbyArea" type="checkbox" value="286"/>
#            south jersey
#            <small>
#             (snj)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_0" name="nearbyArea" type="checkbox" value="556"/>
#            southern maryland
#            <small>
#             (smd)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_45" name="nearbyArea" type="checkbox" value="632"/>
#            southern WV
#            <small>
#             (swv)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_12">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_76" name="nearbyArea" type="checkbox" value="712"/>
#            southwest VA
#            <small>
#             (vaw)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_21" name="nearbyArea" type="checkbox" value="277"/>
#            state college, PA
#            <small>
#             (psu)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_11">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_69" name="nearbyArea" type="checkbox" value="130"/>
#            syracuse, NY
#            <small>
#             (syr)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_56" name="nearbyArea" type="checkbox" value="703"/>
#            tuscarawas co
#            <small>
#             (nph)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_41" name="nearbyArea" type="checkbox" value="704"/>
#            twin tiers NY/PA
#            <small>
#             (tts)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_12">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_75" name="nearbyArea" type="checkbox" value="247"/>
#            utica-rome-oneida
#            <small>
#             (uti)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_33" name="nearbyArea" type="checkbox" value="194"/>
#            west virginia (old)
#            <small>
#             (wva)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_16" name="nearbyArea" type="checkbox" value="329"/>
#            western maryland
#            <small>
#             (wmd)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_26" name="nearbyArea" type="checkbox" value="463"/>
#            williamsport, PA
#            <small>
#             (wpt)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_7" name="nearbyArea" type="checkbox" value="711"/>
#            winchester, VA
#            <small>
#             (okv)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_57" name="nearbyArea" type="checkbox" value="272"/>
#            winston-salem, NC
#            <small>
#             (wsl)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_8" name="nearbyArea" type="checkbox" value="357"/>
#            york, PA
#            <small>
#             (yrk)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_47" name="nearbyArea" type="checkbox" value="252"/>
#            youngstown, OH
#            <small>
#             (yng)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_63" name="nearbyArea" type="checkbox" value="702"/>
#            zanesville / cambridge
#            <small>
#             (zvl)
#            </small>
#           </label>
#          </li>
#          <li>
#           <span class="nextNearbyZone linklike" data-zone="1">
#            + show
#            <span id="nearbyNumber">
#             78
#            </span>
#            more...
#           </span>
#          </li>
#         </ul>
#        </div>
#        <div class="searchgroup">
#         <span class="searchfieldlabel">
#          miles from location
#         </span>
#         <input class="flatinput searchInput search_distance" inputmode="numeric" maxlength="5" name="search_distance" placeholder="miles" size="5" value=""/>
#         <input class="flatinput searchInput postal" name="postal" placeholder="from zip" size="7" type="text" value=""/>
# ...
#         <span class="result-price">
#          $5,500
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-04-17 13:27" title="Sun 17 Apr 01:27:25 PM">
#          Apr 17
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7472425842" href="https://washingtondc.craigslist.org/mld/cto/d/silver-spring-2007-toyota-camry/7472425842.html" id="postid_7472425842">
#           2007 Toyota Camry
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $5,500
#          </span>
#          <span class="result-hood">
#           (Silver Spring)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7472425828">
#        <a class="result-image gallery" data-ids="3:00s0s_71REgvRXXrmz_12w0Mo,3:01010_imonedOjZIpz_12w0Mo,3:01010_1s9B8vVtNGcz_12w0Mo,3:00f0f_4x0m2khlhwyz_12w0Mo,3:00E0E_7VAXfgRezPvz_12w0Mo,3:00J0J_bl5J7IKYu86z_12w0Mo,3:00U0U_6t7dBTPCne8z_0om0t2,3:00O0O_26LWszir1tVz_12w0Mo,3:00d0d_adXdSa5ra71z_12w0Mo,3:00h0h_bHfCImc3Memz_12w0Mo,3:00z0z_erNY01Q9UYNz_12w0Mo,3:00n0n_dnMlgoYeUGLz_12w0Mo,3:00c0c_a8opgfs1vp8z_12w0Mo,3:00R0R_9QY7r8CtM5Mz_12w0Mo,3:01111_lp6d1xlQXKrz_12w0Mo,3:00O0O_j60qePCDDA4z_12w0Mo,3:00N0N_6BJQblb0Sgwz_12w0Mo,3:01717_8snKlInnhPfz_12w0Mo,3:00303_lXydo9zIstJz_12w0Mo,3:00606_1Y7mvo89f9cz_12w0Mo,3:00A0A_elBSfgEnIbUz_12w0Mo,3:00h0h_cw4YbIJrPsSz_12w0Mo,3:00N0N_5WRs90o9fQPz_12w0Mo,3:00r0r_gI0xoWm48irz_12w0Mo" href="https://washingtondc.craigslist.org/nva/cto/d/pasadena-2022-gmc-sierra-1500-at4-new/7472425828.html">
#         <span class="result-price">
#          $76,000
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-04-17 13:27" title="Sun 17 Apr 01:27:22 PM">
#          Apr 17
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7472425828" href="https://washingtondc.craigslist.org/nva/cto/d/pasadena-2022-gmc-sierra-1500-at4-new/7472425828.html" id="postid_7472425828">
#           2022 Gmc sierra 1500 AT4  New Resigned
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $76,000
#          </span>
#          <span class="result-hood">
#           (northern virginia)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7472422035">
#        <a class="result-image gallery" data-ids="3:00505_h0MHdNu53Xuz_1320MM,3:00n0n_3ZBift4uanKz_1320MM,3:00N0N_cSz6FJ5lOSuz_1320MM,3:00M0M_5XEjKtB5EM3z_1320MM,3:00808_6uccLYklvFXz_1320MM,3:00x0x_922qIYr9rB9z_1320MM" href="https://washingtondc.craigslist.org/doc/cto/d/washington-2005-land-rover-lr3-hse/7472422035.html">
#         <span class="result-price">
#          $7,900
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-04-17 13:16" title="Sun 17 Apr 01:16:39 PM">
#          Apr 17
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7472422035" href="https://washingtondc.craigslist.org/doc/cto/d/washington-2005-land-rover-lr3-hse/7472422035.html" id="postid_7472422035">
#           2005 Land Rover LR3 HSE
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $7,900
#          </span>
#          <span class="result-hood">
#           (district of columbia)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7472421383" data-repost-of="5687357498">
#        <a class="result-image gallery" data-ids="3:00l0l_gtWdxJR7Kx3z_0ak06R,3:00X0X_k0m7xZzA0R0z_0CI0pK,3:01313_iVbsUUTs96Yz_0CI0pK,3:00E0E_3yGfNTcxLRsz_0CI0pK,3:01717_dgpPogaEUGPz_0CI0pK,3:00l0l_dRaCx0uZdwpz_0CI0pK,3:00K0K_3GcxUZxcRGRz_0CI0pK,3:00G0G_gsWL3ooWsr2z_0CI0pK,3:00H0H_1NGyje8onhJz_0CI0pK,3:00a0a_3Dne8NhYILnz_0CI0pK,3:00S0S_jW2NcTIVCWlz_0CI0pK,3:00K0K_ddbQKIwiO7Fz_0CI0pK,3:00z0z_9NEMRpa15B9z_0CI0pK,3:00O0O_c6rW9Vo1NAMz_0CI0pK,3:00g0g_9EPGvEa5Gfwz_0CI0pK,3:00l0l_6mzwU3FJ7YLz_0CI0pK,3:01313_11sDwahU5Blz_0CI0pK,3:00909_e4c7OlDJTkmz_0CI0pK,3:00b0b_aOqYUSOmYGz_0CI0pK,3:00q0q_1QB2hYMS0aJz_0CI0pK,3:00j0j_O22uD79zhYz_0CI0pK,3:00S0S_9NgzerpTi5kz_0CI0pK,3:00M0M_5baWvfOPyeHz_0CI0pK,3:00a0a_4GenxqIJoMez_0CI0pK" href="https://washingtondc.craigslist.org/nva/ctd/d/2007-toyota-camry-xle-soper-low-miles/7472421383.html">
#         <span class="result-price">
#          $11,799
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2022-04-17 13:14" title="Sun 17 Apr 01:14:51 PM">
#          Apr 17
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7472421383" href="https://washingtondc.craigslist.org/nva/ctd/d/2007-toyota-camry-xle-soper-low-miles/7472421383.html" id="postid_7472421383">
#           2007 TOYOTA CAMRY XLE SOPER LOW MILES
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $11,799
#          </span>
#          <span class="result-hood">
#           (MANASSAS)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#      </ul>
#     </div>
#     <div class="search-legend bottom">
#      <div class="search-view">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="search-sort">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="paginator buttongroup firstpage">
#       <span class="resulttotal">
#        <span class="for-map">
#         showing
#         <span class="displaycountShow">
#          ...
#         </span>
#         postings
#         <span class="zoom-out-for-more" style="display: none">
#          -
#          <a href="">
#           zoom out for all
#           <span class="total">
#            3000
#           </span>
#          </a>
#         </span>
#        </span>
#       </span>
#       <span class="buttons">
#        <a class="button first" href="/search/cta" title="first page">
#         &lt;&lt;
#        </a>
#        <span class="button first" title="first page">
#         &lt;&lt;
#        </span>
#        <a class="button prev" href="/search/cta" title="previous page">
#         &lt; prev
#        </a>
#        <span class="button prev" title="previous page">
#         &lt; prev
#        </span>
#        <span class="button pagenum">
#         <span class="range">
#          <span class="rangeFrom">
#           1
#          </span>
#          -
#          <span class="rangeTo">
#           120
#          </span>
#         </span>
#         /
#         <span class="totalcount">
#          3000
#         </span>
#        </span>
#        <a class="button next" href="/search/cta?s=120" title="next page">
#         next &gt;
#        </a>
#        <span class="button next" title="next page">
#         next &gt;
#        </span>
#       </span>
#      </div>
#     </div>
#     <section class="blurbs">
#     </section>
#     <div id="floater">
#      <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif"/>
#      <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif"/>
#     </div>
#    </form>
#    <aside class="tsb">
#     <ul>
#      <li>
#       <a href="https://www.craigslist.org/about/safety">
#        safety tips
#       </a>
#       <li>
#        <a href="https://www.craigslist.org/about/prohibited">
#         prohibited items
#        </a>
#        <li>
#         <a href="https://www.craigslist.org/about/recalled_items">
#          product recalls
#         </a>
#         <li>
#          <a href="https://www.craigslist.org/about/scams">
#           avoiding scams
#          </a>
#         </li>
#        </li>
#       </li>
#      </li>
#     </ul>
#    </aside>
#    <div class="slidemessage">
#     <span class="fave">
#      <span class="star">
#      </span>
#      favorited
#     </span>
#     <span class="unfave">
#      <span class="star">
#      </span>
#      no longer favorited
#     </span>
#     <span class="hide">
#      <span class="trash">
#      </span>
#      hidden
#     </span>
#     <span class="unhide">
#      <span class="trash">
#      </span>
#      no longer hidden
#     </span>
#    </div>
#    <footer>
#     <ul class="clfooter">
#      <li>
#       © 2022
#       <span class="desktop">
#        craigslist
#       </span>
#       <span class="mobile">
#        CL
#       </span>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/help/">
#        help
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/scams">
#        safety
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/privacy.policy">
#        privacy
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://forums.craigslist.org/?forumID=8">
#        feedback
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/terms.of.use">
#        terms
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/">
#        about
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/craigslist_app">
#        craigslist app
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/craigslist_is_hiring">
#        cl is hiring
#       </a>
#      </li>
#     </ul>
#    </footer>
#   </section>
#   <template id="gallerycarousel">
#    <div class="slider-info">
#    </div>
#    <div class="slider-back arrow">
#     ‹
#    </div>
#    <div class="slider-forward arrow">
#     ›
#    </div>
#   </template>
#   <script id="clustertemplate" type="text/template">
#    <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{price}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     unhide
#                 </span>
#             </span>
#         </div>
#     </li>
#   </script>
#   <script id="postingtemplate" type="text/template">
#    <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{price}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">hide this posting</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">unhide</span>
#                         unhide
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lsaquo;</span><span class="slider-info"></span><span class="slider-forward arrow">&rsaquo;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <div class="timecontainer"></div>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
#   </script>
#   <script id="popuptemplate" type="text/template">
#    <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
#   </script>
#  </body>
# </html>

# %% [markdown]
# Now lets dig in to find relevant data, before that we need to read the html file to see what we are looking for.
#
# For this we go to our target webpage  and inspects it content.
#
# - Open the webpage on your browser.
# - Right click and then select *Inspect*, on the relevant information on the webpage. This will open the html version of the webpage on your browser.
# - Identify the tag in which the relevant information is stored.

# %% [markdown]
# - The most important element in html is, *tags*. A tag is Each tag can have multiple attributes, *class* and *ID* are some of the most common attributes that uniquely identify the tag (by possessing important information). The relevant data is generally text between these tags (start and end tags), for example \<a\> and \</a\>.
# - In order to access data between texts, `.text` or the function `.get_text()` or `getText()` can be used. All have similar functionality, however the function versions give more control to manipulate the data.
# - If the relevant data is the value of some attribute, `get()` function can be used to get the value.
# - To search using tags, class or ID, two functions can be used (there are others as well):
#     - `find()`: returns the first instance of the tag to be found.
#     - `find_all()`: returns all instances of the tag to be found. returns a list of items.

# %%
# single search
soup.find('div')
# Out:
# <div id="curtain">
# <div class="cover"></div>
# <div class="content">
# <div class="icom-"></div>
# <div class="text loading">loading</div>
# <div class="text reading">reading</div>
# <div class="text writing">writing</div>
# <div class="text saving">saving</div>
# <div class="text searching">searching</div>
# <div class="text unrecoverable">
#                 There was an error loading the page; please try to
#                 <a href="#" id="cl-unrecoverable-hard-refresh" onclick="location.reload(true);">refresh the page.</a>
# </div>
# <div class="text message"></div>
# </div>
# </div>

# %%
soup.find_all('div')

#len(soup.find_all('div'))
# Out:
# [<div id="curtain">
#  <div class="cover"></div>
#  <div class="content">
#  <div class="icom-"></div>
#  <div class="text loading">loading</div>
#  <div class="text reading">reading</div>
#  <div class="text writing">writing</div>
#  <div class="text saving">saving</div>
#  <div class="text searching">searching</div>
#  <div class="text unrecoverable">
#                  There was an error loading the page; please try to
#                  <a href="#" id="cl-unrecoverable-hard-refresh" onclick="location.reload(true);">refresh the page.</a>
#  </div>
#  <div class="text message"></div>
#  </div>
#  </div>,
#  <div class="cover"></div>,
#  <div class="content">
#  <div class="icom-"></div>
#  <div class="text loading">loading</div>
#  <div class="text reading">reading</div>
#  <div class="text writing">writing</div>
#  <div class="text saving">saving</div>
#  <div class="text searching">searching</div>
#  <div class="text unrecoverable">
#                  There was an error loading the page; please try to
#                  <a href="#" id="cl-unrecoverable-hard-refresh" onclick="location.reload(true);">refresh the page.</a>
#  </div>
#  <div class="text message"></div>
#  </div>,
#  <div class="icom-"></div>,
#  <div class="text loading">loading</div>,
#  <div class="text reading">reading</div>,
#  <div class="text writing">writing</div>,
#  <div class="text saving">saving</div>,
#  <div class="text searching">searching</div>,
#  <div class="text unrecoverable">
#                  There was an error loading the page; please try to
#                  <a href="#" id="cl-unrecoverable-hard-refresh" onclick="location.reload(true);">refresh the page.</a>
#  </div>,
#  <div class="text message"></div>,
#  <div>
#  <p>We've detected that JavaScript is not enabled in your browser.</p>
#  <p>You must enable JavaScript to use craigslist.</p>
#  </div>,
#  <div id="unsupported-browser">
#  <p>We've detected you are using a browser that is missing critical features.</p>
#  <p>Please visit craigslist from a modern browser.</p>
#  </div>,
#  <div class="bglogo"></div>,
#  <div class="userlinks">
#  <ul class="user-actions">
#  <li class="user post">
#  <a href="https://post.craigslist.org/c/wdc">post</a>
#  </li>
#  <li class="user account">
#  <a href="https://accounts.craigslist.org/login/home">account</a>
#  </li>
#  </ul>
#  <ul class="user-favs-discards">
#  <li class="user">
#  <div class="favorites">
#  <a class="favlink" href="#"><span aria-hidden="true" class="icon icon-star fav"></span><span class="fav-number">0</span><span class="fav-label"> favorites</span></a>
#  </div>
#  </li>
#  <li class="user discards">
#  <div class="to-banish-page">
#  <a class="to-banish-page-link" href="#">
#  <span aria-hidden="true" class="icon icon-trash red"></span>
#  <span class="banished_count">0</span>
#  <span class="discards-label"> hidden</span>
#  </a>
#  </div>
#  </li>
#  </ul>
#  </div>,
#  <div class="favorites">
#  <a class="favlink" href="#"><span aria-hidden="true" class="icon icon-star fav"></span><span class="fav-number">0</span><span class="fav-label"> favorites</span></a>
#  </div>,
#  <div class="to-banish-page">
#  <a class="to-banish-page-link" href="#">
#  <span aria-hidden="true" class="icon icon-trash red"></span>
#  <span class="banished_count">0</span>
#  <span class="discards-label"> hidden</span>
#  </a>
#  </div>,
#  <div class="querybox">
#  <div class="form-tab js-only"><span class="search-open" title="hide search">«</span><span class="search-closed" title="show search">»</span></div>
#  <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search cars &amp; trucks" type="text" value=""/>
#  <button class="searchbtn" type="submit">
#  <span aria-hidden="true" class="icon icon-search"></span>
#  <span class="screen-reader-text">press to search craigslist</span>
#  </button>
#  <div class="savealert">
#  <a class="saveme" data-action="save" href="https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Fwashingtondc%2Ecraigslist%2Eorg%2Fsearch%2Fcta" title="save this search">save search</a>
#  </div>
#  </div>,
#  <div class="form-tab js-only"><span class="search-open" title="hide search">«</span><span class="search-closed" title="show search">»</span></div>,
#  <div class="savealert">
#  <a class="saveme" data-action="save" href="https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Fwashingtondc%2Ecraigslist%2Eorg%2Fsearch%2Fcta" title="save this search">save search</a>
#  </div>,
#  <div class="search-options-container">
#  <h1 class="cattitle">
#  <a class="reset" href="https://washingtondc.craigslist.org/search/cta" title="clear all search parameters">cars &amp; trucks</a>
#  </h1>
#  <div class="search-options-header linklike">
#  <div aria-hidden="true" class="icon icon-toggle-gear"></div>
#          options<span class="options-close">close</span>
#  </div>
#  <input id="excats" name="excats" type="hidden"/>
#  <div class="search-options">
#  <div class="searchgroup categories">
#  </div>
#  <input name="userid" type="hidden" value="">
#  <div id="purveyor">
#  <ul class="searchgroup buttongroup purveyor">
#  <li class="button sel">
#  <a data-val="all" href="/search/cta" id="all-purveyor">all</a>
#  </li><li class="button">
#  <a data-val="owner" href="/search/cta?purveyor=owner" id="owner-purveyor"> owner</a>
#  </li><li class="button">
#  <a data-val="dealer" href="/search/cta?purveyor=dealer" id="dealer-purveyor">dealer</a>
#  </li>
#  </ul>
#  </div>
#  <div class="searchgroup" id="basic-bools">
#  <ul>
#  <li>
#  <label class="srchType">
#  <input class="" name="srchType" type="checkbox" value="T"/>
#             search titles only
#         </label>
#  </li>
#  <li>
#  <label class="hasPic">
#  <input class="autosubmit" name="hasPic" type="checkbox" value="1"/>
#             has image
#         </label>
#  </li>
#  <li>
#  <label class="postedToday">
#  <input class="autosubmit" name="postedToday" type="checkbox" value="1"/>
#             posted today
#         </label>
#  </li>
#  <li>
#  <label class="bundleDuplicates">
#  <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1"/>
#             bundle duplicates
#         </label>
#  </li>
#  <li>
#  <label class="searchNearby">
#  <input class="autosubmit" name="searchNearby" type="checkbox" value="1"/>
#             include nearby areas
#         </label>
#  </li>
#  </ul>
#  <ul class="js-only nearbyAreas">
#  <li class="nearbyZone nearbyZone_10">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_64" name="nearbyArea" type="checkbox" value="251">
#                              akron / canton <small>(cak)</small>
#  </input></label>
#  </li>
#  <li class="nearbyZone nearbyZone_3">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_20" name="nearbyArea" type="checkbox" value="355">
#                              altoona-johnstown <small>(aoo)</small>
#  </input></label>
#  </li>
#  <li class="">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_1" name="nearbyArea" type="checkbox" value="460">
#                              annapolis, MD <small>(anp)</small>
#  </input></label>
#  </li>
#  <li class="nearbyZone nearbyZone_11">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_66" name="nearbyArea" type="checkbox" value="700">
#                              ashtabula, OH <small>(jfn)</small>
#  </input></label>
#  </li>
#  <li class="nearbyZone nearbyZone_10">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_60" name="nearbyArea" type="checkbox" value="438">
#                              athens, OH <small>(ohu)</small>
#  </input></label>
#  </li>
#  <li class="">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_2" name="nearbyArea" type="checkbox" value="34">
#                              baltimore, MD <small>(bal)</small>
#  </input></label>
#  </li>
#  <li class="nearbyZone nearbyZone_7">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_43" name="nearbyArea" type="checkbox" value="248"/>
#                              binghamton, NY <small>(bgm)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_11">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_70" name="nearbyArea" type="checkbox" value="40"/>
#                              buffalo, NY <small>(buf)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_9">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_55" name="nearbyArea" type="checkbox" value="451"/>
#                              catskills <small>(cat)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_4">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_25" name="nearbyArea" type="checkbox" value="349"/>
#                              central NJ <small>(cnj)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_8">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_52" name="nearbyArea" type="checkbox" value="439"/>
#                              charleston, WV <small>(crw)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_2">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_14" name="nearbyArea" type="checkbox" value="290"/>
#                              charlottesville, VA <small>(uva)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_9">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_58" name="nearbyArea" type="checkbox" value="452"/>
#                              chautauqua, NY <small>(chq)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_12">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_74" name="nearbyArea" type="checkbox" value="27"/>
#                              cleveland, OH <small>(cle)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_1">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_9" name="nearbyArea" type="checkbox" value="705"/>
#                              cumberland valley <small>(cbg)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_5">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_35" name="nearbyArea" type="checkbox" value="367"/>
#                              danville <small>(dnv)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_1">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_10" name="nearbyArea" type="checkbox" value="193"/>
#                              delaware <small>(dlw)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_12">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_77" name="nearbyArea" type="checkbox" value="281"/>
#                              eastern CT <small>(nlo)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_7">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_42" name="nearbyArea" type="checkbox" value="335"/>
#                              eastern NC <small>(enc)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_1">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_6" name="nearbyArea" type="checkbox" value="444"/>
#                              eastern panhandle <small>(ewv)</small>
#  </label>
#  </li>
#  <li class="">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_5" name="nearbyArea" type="checkbox" value="328"/>
#                              eastern shore <small>(esh)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_6">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_40" name="nearbyArea" type="checkbox" value="453"/>
#                              elmira-corning <small>(elm)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_10">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_62" name="nearbyArea" type="checkbox" value="275"/>
#                              erie, PA <small>(eri)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_10">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_65" name="nearbyArea" type="checkbox" value="273"/>
#                              fayetteville, NC <small>(fay)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_8">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_51" name="nearbyArea" type="checkbox" value="685"/>
#                              finger lakes, NY <small>(fgl)</small>
#  </label>
#  </li>
#  <li class="">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_3" name="nearbyArea" type="checkbox" value="633"/>
#                              frederick, MD <small>(fdk)</small>
#  </label>
#  </li>
#  <li class="">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_4" name="nearbyArea" type="checkbox" value="457"/>
#                              fredericksburg, VA <small>(ezf)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_8">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_49" name="nearbyArea" type="checkbox" value="61"/>
#                              greensboro, NC <small>(gbo)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_2">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_12" name="nearbyArea" type="checkbox" value="166"/>
#                              harrisburg, PA <small>(hrs)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_2">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_15" name="nearbyArea" type="checkbox" value="447"/>
#                              harrisonburg, VA <small>(shd)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_12">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_73" name="nearbyArea" type="checkbox" value="44"/>
#                              hartford, CT <small>(htf)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_9">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_54" name="nearbyArea" type="checkbox" value="249"/>
#                              hudson valley, NY <small>(hud)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_11">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_71" name="nearbyArea" type="checkbox" value="442"/>
#                              huntington-ashland <small>(hts)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_8">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_50" name="nearbyArea" type="checkbox" value="201"/>
#                              ithaca, NY <small>(ith)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_11">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_67" name="nearbyArea" type="checkbox" value="634"/>
#                              jacksonville, NC <small>(oaj)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_4">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_28" name="nearbyArea" type="checkbox" value="561"/>
#                              jersey shore <small>(jys)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_1">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_11" name="nearbyArea" type="checkbox" value="279"/>
#                              lancaster, PA <small>(lns)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_3">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_22" name="nearbyArea" type="checkbox" value="167"/>
#                              lehigh valley <small>(alt)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_8">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_48" name="nearbyArea" type="checkbox" value="250"/>
#                              long island, NY <small>(isp)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_4">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_24" name="nearbyArea" type="checkbox" value="366"/>
#                              lynchburg, VA <small>(lyn)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_8">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_53" name="nearbyArea" type="checkbox" value="706"/>
#                              meadville, PA <small>(mdv)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_4">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_27" name="nearbyArea" type="checkbox" value="440"/>
#                              morgantown, WV <small>(wvu)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_10">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_61" name="nearbyArea" type="checkbox" value="168"/>
#                              new haven, CT <small>(hvn)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_6">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_39" name="nearbyArea" type="checkbox" value="291"/>
#                              new river valley <small>(vpi)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_5">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_34" name="nearbyArea" type="checkbox" value="3"/>
#                              new york city <small>(nyc)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_3">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_23" name="nearbyArea" type="checkbox" value="48"/>
#                              norfolk / hampton roads <small>(nfk)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_6">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_36" name="nearbyArea" type="checkbox" value="170"/>
#                              north jersey <small>(njy)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_6">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_38" name="nearbyArea" type="checkbox" value="443"/>
#                              northern panhandle <small>(whl)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_11">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_68" name="nearbyArea" type="checkbox" value="354"/>
#                              northwest CT <small>(nct)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_9">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_59" name="nearbyArea" type="checkbox" value="684"/>
#                              oneonta, NY <small>(onh)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_6">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_37" name="nearbyArea" type="checkbox" value="336"/>
#                              outer banks <small>(obx)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_7">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_46" name="nearbyArea" type="checkbox" value="441"/>
#                              parkersburg-marietta <small>(pkb)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_3">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_19" name="nearbyArea" type="checkbox" value="17"/>
#                              philadelphia <small>(phi)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_5">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_31" name="nearbyArea" type="checkbox" value="33"/>
#                              pittsburgh, PA <small>(pit)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_4">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_29" name="nearbyArea" type="checkbox" value="356"/>
#                              poconos <small>(poc)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_7">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_44" name="nearbyArea" type="checkbox" value="36"/>
#                              raleigh / durham / CH <small>(ral)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_3">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_18" name="nearbyArea" type="checkbox" value="278"/>
#                              reading, PA <small>(rea)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_2">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_13" name="nearbyArea" type="checkbox" value="60"/>
#                              richmond, VA <small>(ric)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_5">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_32" name="nearbyArea" type="checkbox" value="289"/>
#                              roanoke, VA <small>(roa)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_12">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_72" name="nearbyArea" type="checkbox" value="126"/>
#                              rochester, NY <small>(rcs)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_5">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_30" name="nearbyArea" type="checkbox" value="276"/>
#                              scranton / wilkes-barre <small>(avp)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_2">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_17" name="nearbyArea" type="checkbox" value="286"/>
#                              south jersey <small>(snj)</small>
#  </label>
#  </li>
#  <li class="">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_0" name="nearbyArea" type="checkbox" value="556"/>
#                              southern maryland <small>(smd)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_7">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_45" name="nearbyArea" type="checkbox" value="632"/>
#                              southern WV <small>(swv)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_12">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_76" name="nearbyArea" type="checkbox" value="712"/>
#                              southwest VA <small>(vaw)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_3">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_21" name="nearbyArea" type="checkbox" value="277"/>
#                              state college, PA <small>(psu)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_11">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_69" name="nearbyArea" type="checkbox" value="130"/>
#                              syracuse, NY <small>(syr)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_9">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_56" name="nearbyArea" type="checkbox" value="703"/>
#                              tuscarawas co <small>(nph)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_6">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_41" name="nearbyArea" type="checkbox" value="704"/>
#                              twin tiers NY/PA <small>(tts)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_12">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_75" name="nearbyArea" type="checkbox" value="247"/>
#                              utica-rome-oneida <small>(uti)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_5">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_33" name="nearbyArea" type="checkbox" value="194"/>
#                              west virginia (old) <small>(wva)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_2">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_16" name="nearbyArea" type="checkbox" value="329"/>
#                              western maryland <small>(wmd)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_4">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_26" name="nearbyArea" type="checkbox" value="463"/>
#                              williamsport, PA <small>(wpt)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_1">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_7" name="nearbyArea" type="checkbox" value="711"/>
#                              winchester, VA <small>(okv)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_9">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_57" name="nearbyArea" type="checkbox" value="272"/>
#                              winston-salem, NC <small>(wsl)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_1">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_8" name="nearbyArea" type="checkbox" value="357"/>
#                              york, PA <small>(yrk)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_7">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_47" name="nearbyArea" type="checkbox" value="252"/>
#                              youngstown, OH <small>(yng)</small>
#  </label>
#  </li>
#  <li class="nearbyZone nearbyZone_10">
#  <label class="nearby">
#  <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_63" name="nearbyArea" type="checkbox" value="702"/>
#                              zanesville / cambridge <small>(zvl)</small>
#  </label>
#  </li>
#  <li>
#  <span class="nextNearbyZone linklike" data-zone="1">
#                              + show <span id="nearbyNumber">78</span> more...
#                          </span>
#  </li>
#  </ul>
#  </div>
#  <div class="searchgroup">
#  <span class="searchfieldlabel">miles from location</span>
#  <input class="flatinput searchInput search_distance" inputmode="numeric" maxlength="5" name="search_distance" placeholder="miles" size="5" value=""/>
#  <input class="flatinput searchInput postal" name="postal" placeholder="from zip" size="7" type="text" value=""/>
#  <span class="icon icon-locate"></span>
#  </div>
#  <div class="searchgroup minmax price" id="price">
#  <span class="searchfieldlabel">price</span>
#  <input class="flatinput min" name="min_price" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
#  <input class="flatinput max" name="max_price" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
#  </div>
#  <div class="searchgroup search-group-text">
#  <span class="searchfieldlabel">make and model</span>
#  <input class="flatinput auto_make_model" data-autocomplete="makemodel" name="auto_make_model" placeholder="make / model" type="text" value="">
#  </input></div>
#  <div class="searchgroup search-group-range">
#  <div class="minmax auto_year">
#  <span class="searchfieldlabel">model year</span>
#  <input class="flatinput min" name="min_auto_year" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
#  <input class="flatinput max" name="max_auto_year" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
#  </div>
#  <div class="minmax auto_miles">
#  <span class="searchfieldlabel">odometer</span>
#  <input class="flatinput min" name="min_auto_miles" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
#  <input class="flatinput max" name="max_auto_miles" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
#  </div>
#  </div>
#  <div class="searchgroup search-group-multi_checkbox">
#  <div class="search-attribute hide-list" data-attr="condition">
#  <div class="title linklike">
#  <span class="plus">▸</span><span class="minus">▾</span> condition
#      </div>
#  <ul class="list">
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="condition_10" name="condition" type="checkbox" value="10">
#                      new
#                  </input></label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="condition_20" name="condition" type="checkbox" value="20">
#                      like new
#                  </input></label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="condition_30" name="condition" type="checkbox" value="30">
#                      excellent
#                  </input></label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="condition_40" name="condition" type="checkbox" value="40">
#                      good
#                  </input></label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="condition_50" name="condition" type="checkbox" value="50">
#                      fair
#                  </input></label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="condition_60" name="condition" type="checkbox" value="60">
#                      salvage
#                  </input></label>
#  </li>
#  </ul>
#  </div>
#  <div class="search-attribute hide-list" data-attr="auto_cylinders">
#  <div class="title linklike">
#  <span class="plus">▸</span><span class="minus">▾</span> cylinders
#      </div>
#  <ul class="list">
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_cylinders_1" name="auto_cylinders" type="checkbox" value="1"/>
#                      3 cylinders
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_cylinders_2" name="auto_cylinders" type="checkbox" value="2"/>
#                      4 cylinders
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_cylinders_3" name="auto_cylinders" type="checkbox" value="3"/>
#                      5 cylinders
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_cylinders_4" name="auto_cylinders" type="checkbox" value="4"/>
#                      6 cylinders
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_cylinders_5" name="auto_cylinders" type="checkbox" value="5"/>
#                      8 cylinders
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_cylinders_6" name="auto_cylinders" type="checkbox" value="6"/>
#                      10 cylinders
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_cylinders_7" name="auto_cylinders" type="checkbox" value="7"/>
#                      12 cylinders
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_cylinders_8" name="auto_cylinders" type="checkbox" value="8"/>
#                      other
#                  </label>
#  </li>
#  <li class="selectall js-only">
#  <span class="all">select all</span>
#  <span class="none">deselect all</span>
#  </li>
#  </ul>
#  </div>
#  <div class="search-attribute hide-list" data-attr="auto_drivetrain">
#  <div class="title linklike">
#  <span class="plus">▸</span><span class="minus">▾</span> drive
#      </div>
#  <ul class="list">
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_drivetrain_1" name="auto_drivetrain" type="checkbox" value="1"/>
#                      fwd
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_drivetrain_2" name="auto_drivetrain" type="checkbox" value="2"/>
#                      rwd
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_drivetrain_3" name="auto_drivetrain" type="checkbox" value="3"/>
#                      4wd
#                  </label>
#  </li>
#  </ul>
#  </div>
#  <div class="search-attribute hide-list" data-attr="auto_fuel_type">
#  <div class="title linklike">
#  <span class="plus">▸</span><span class="minus">▾</span> fuel
#      </div>
#  <ul class="list">
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_fuel_type_1" name="auto_fuel_type" type="checkbox" value="1"/>
#                      gas
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_fuel_type_2" name="auto_fuel_type" type="checkbox" value="2"/>
#                      diesel
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_fuel_type_3" name="auto_fuel_type" type="checkbox" value="3"/>
#                      hybrid
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_fuel_type_4" name="auto_fuel_type" type="checkbox" value="4"/>
#                      electric
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_fuel_type_6" name="auto_fuel_type" type="checkbox" value="6"/>
#                      other
#                  </label>
#  </li>
#  </ul>
#  </div>
#  <div class="search-attribute hide-list" data-attr="auto_paint">
#  <div class="title linklike">
#  <span class="plus">▸</span><span class="minus">▾</span> paint color
#      </div>
#  <ul class="list">
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_paint_1" name="auto_paint" type="checkbox" value="1"/>
#                      black
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_paint_2" name="auto_paint" type="checkbox" value="2"/>
#                      blue
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_paint_20" name="auto_paint" type="checkbox" value="20"/>
#                      brown
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_paint_3" name="auto_paint" type="checkbox" value="3"/>
#                      green
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_paint_4" name="auto_paint" type="checkbox" value="4"/>
#                      grey
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_paint_5" name="auto_paint" type="checkbox" value="5"/>
#                      orange
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_paint_6" name="auto_paint" type="checkbox" value="6"/>
#                      purple
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_paint_7" name="auto_paint" type="checkbox" value="7"/>
#                      red
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_paint_8" name="auto_paint" type="checkbox" value="8"/>
#                      silver
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_paint_9" name="auto_paint" type="checkbox" value="9"/>
#                      white
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_paint_10" name="auto_paint" type="checkbox" value="10"/>
#                      yellow
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_paint_11" name="auto_paint" type="checkbox" value="11"/>
#                      custom
#                  </label>
#  </li>
#  <li class="selectall js-only">
#  <span class="all">select all</span>
#  <span class="none">deselect all</span>
#  </li>
#  </ul>
#  </div>
#  <div class="search-attribute hide-list" data-attr="auto_size">
#  <div class="title linklike">
#  <span class="plus">▸</span><span class="minus">▾</span> size
#      </div>
#  <ul class="list">
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_size_1" name="auto_size" type="checkbox" value="1"/>
#                      compact
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_size_2" name="auto_size" type="checkbox" value="2"/>
#                      full-size
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_size_3" name="auto_size" type="checkbox" value="3"/>
#                      mid-size
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_size_4" name="auto_size" type="checkbox" value="4"/>
#                      sub-compact
#                  </label>
#  </li>
#  </ul>
#  </div>
#  <div class="search-attribute hide-list" data-attr="auto_title_status">
#  <div class="title linklike">
#  <span class="plus">▸</span><span class="minus">▾</span> title status
#      </div>
#  <ul class="list">
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_title_status_1" name="auto_title_status" type="checkbox" value="1"/>
#                      clean
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_title_status_2" name="auto_title_status" type="checkbox" value="2"/>
#                      salvage
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_title_status_3" name="auto_title_status" type="checkbox" value="3"/>
#                      rebuilt
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_title_status_4" name="auto_title_status" type="checkbox" value="4"/>
#                      parts only
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_title_status_5" name="auto_title_status" type="checkbox" value="5"/>
#                      lien
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_title_status_6" name="auto_title_status" type="checkbox" value="6"/>
#                      missing
#                  </label>
#  </li>
#  </ul>
#  </div>
#  <div class="search-attribute hide-list" data-attr="auto_transmission">
#  <div class="title linklike">
#  <span class="plus">▸</span><span class="minus">▾</span> transmission
#      </div>
#  <ul class="list">
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_transmission_1" name="auto_transmission" type="checkbox" value="1"/>
#                      manual
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_transmission_2" name="auto_transmission" type="checkbox" value="2"/>
#                      automatic
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_transmission_3" name="auto_transmission" type="checkbox" value="3"/>
#                      other
#                  </label>
#  </li>
#  </ul>
#  </div>
#  <div class="search-attribute hide-list" data-attr="auto_bodytype">
#  <div class="title linklike">
#  <span class="plus">▸</span><span class="minus">▾</span> type
#      </div>
#  <ul class="list">
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_bodytype_1" name="auto_bodytype" type="checkbox" value="1"/>
#                      bus
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_bodytype_2" name="auto_bodytype" type="checkbox" value="2"/>
#                      convertible
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_bodytype_3" name="auto_bodytype" type="checkbox" value="3"/>
#                      coupe
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_bodytype_4" name="auto_bodytype" type="checkbox" value="4"/>
#                      hatchback
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_bodytype_5" name="auto_bodytype" type="checkbox" value="5"/>
#                      mini-van
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_bodytype_6" name="auto_bodytype" type="checkbox" value="6"/>
#                      offroad
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_bodytype_7" name="auto_bodytype" type="checkbox" value="7"/>
#                      pickup
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_bodytype_8" name="auto_bodytype" type="checkbox" value="8"/>
#                      sedan
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_bodytype_9" name="auto_bodytype" type="checkbox" value="9"/>
#                      truck
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_bodytype_10" name="auto_bodytype" type="checkbox" value="10"/>
#                      SUV
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_bodytype_11" name="auto_bodytype" type="checkbox" value="11"/>
#                      wagon
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_bodytype_12" name="auto_bodytype" type="checkbox" value="12"/>
#                      van
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="auto_bodytype_13" name="auto_bodytype" type="checkbox" value="13"/>
#                      other
#                  </label>
#  </li>
#  <li class="selectall js-only">
#  <span class="all">select all</span>
#  <span class="none">deselect all</span>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="searchgroup search-group-checkbox">
#  <label class="crypto_currency_ok">
#  <input class="autosubmit" name="crypto_currency_ok" type="checkbox" value="1"/>
#      cryptocurrency ok
#  </label><br/>
#  <label class="delivery_available">
#  <input class="autosubmit" name="delivery_available" type="checkbox" value="1"/>
#      delivery available
#  </label><br/>
#  </div>
#  <div class="searchgroup search-group-multi_checkbox">
#  <div class="search-attribute hide-list" data-attr="language">
#  <div class="title linklike">
#  <span class="plus">▸</span><span class="minus">▾</span> language of posting
#      </div>
#  <ul class="list">
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_1" name="language" type="checkbox" value="1"/>
#                      afrikaans
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_2" name="language" type="checkbox" value="2"/>
#                      català
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_3" name="language" type="checkbox" value="3"/>
#                      dansk
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_4" name="language" type="checkbox" value="4"/>
#                      deutsch
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_5" name="language" type="checkbox" value="5"/>
#                      english
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_6" name="language" type="checkbox" value="6"/>
#                      español
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_7" name="language" type="checkbox" value="7"/>
#                      suomi
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_8" name="language" type="checkbox" value="8"/>
#                      français
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_9" name="language" type="checkbox" value="9"/>
#                      italiano
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_10" name="language" type="checkbox" value="10"/>
#                      nederlands
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_11" name="language" type="checkbox" value="11"/>
#                      norsk
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_12" name="language" type="checkbox" value="12"/>
#                      português
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_13" name="language" type="checkbox" value="13"/>
#                      svenska
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_14" name="language" type="checkbox" value="14"/>
#                      filipino
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_15" name="language" type="checkbox" value="15"/>
#                      türkçe
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_16" name="language" type="checkbox" value="16"/>
#                      中文
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_17" name="language" type="checkbox" value="17"/>
#                      العربية
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_18" name="language" type="checkbox" value="18"/>
#                      日本語
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_19" name="language" type="checkbox" value="19"/>
#                      한국말
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_20" name="language" type="checkbox" value="20"/>
#                      русский
#                  </label>
#  </li>
#  <li class="checkbox">
#  <label>
#  <input class="multi_checkbox" id="language_21" name="language" type="checkbox" value="21"/>
#                      tiếng việt
#                  </label>
#  </li>
#  <li class="selectall js-only">
#  <span class="all">select all</span>
#  <span class="none">deselect all</span>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="searchgroup resetsearch">
#  <a class="reset linklike" href="https://washingtondc.craigslist.org/search/cta" title="clear all search parameters">reset</a>
#  <button class="searchlink linklike" type="submit">update search</button>
#  </div>
#  <aside class="tsb">
#  <ul>
#  <li><a href="https://www.craigslist.org/about/safety">safety tips</a>
#  <li><a href="https://www.craigslist.org/about/prohibited">prohibited items</a>
#  <li><a href="https://www.craigslist.org/about/recalled_items">product recalls</a>
# ...
#  </span>
#  <time class="result-date" datetime="2022-04-17 13:46" title="Sun 17 Apr 01:46:24 PM">Apr 17</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7472432411" href="https://washingtondc.craigslist.org/nva/cto/d/manassas-toyota-camry-2016-se/7472432411.html" id="postid_7472432411">Toyota Camry 2016 SE</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-price">$16,500</span>
#  <span class="result-hood"> (Manassas)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2022-04-17 13:45" title="Sun 17 Apr 01:45:23 PM">Apr 17</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7472432086" href="https://washingtondc.craigslist.org/nva/ctd/d/garrisonville-2004-ford-explorer-sport/7472432086.html" id="postid_7472432086">2004 FORD EXPLORER SPORT</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-price">$7,400</span>
#  <span class="result-hood"> (2004 FORD EXPLORER SPORT)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2022-04-17 13:44" title="Sun 17 Apr 01:44:19 PM">Apr 17</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7472431689" href="https://washingtondc.craigslist.org/mld/cto/d/gaithersburg-toyota-avalon-sale/7472431689.html" id="postid_7472431689">Toyota Avalon 4 Sale</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-price">$4,250</span>
#  <span class="result-hood"> (gaithersburg)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2022-04-17 13:44" title="Sun 17 Apr 01:44:19 PM">Apr 17</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7472431688" href="https://washingtondc.craigslist.org/nva/cto/d/reston-2015-bmw-x3-xdrive35i-sport/7472431688.html" id="postid_7472431688">2015 BMW x3 xDrive35i Sport Utility 4D</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-price">$13,500</span>
#  <span class="result-hood"> (Reston)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2022-04-17 13:42" title="Sun 17 Apr 01:42:43 PM">Apr 17</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7472431196" href="https://washingtondc.craigslist.org/nva/ctd/d/manassas-2012-gmc-acadia-denali-months/7472431196.html" id="postid_7472431196">2012 GMC ACADIA DENALI 6 MONTHS WARRANTY INCLUDED</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-price">$15,983</span>
#  <span class="result-hood"> (+ Beyond Motors LLC)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2022-04-17 13:39" title="Sun 17 Apr 01:39:19 PM">Apr 17</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7472430011" href="https://washingtondc.craigslist.org/nva/cto/d/centreville-kia-niro-lx-hybrid/7472430011.html" id="postid_7472430011">Kia Niro LX Hybrid</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-price">$16,800</span>
#  <span class="result-hood"> (Centreville)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2022-04-17 13:32" title="Sun 17 Apr 01:32:28 PM">Apr 17</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7472427588" href="https://washingtondc.craigslist.org/mld/cto/d/waldorf-2012-nissan-quest-sv/7472427588.html" id="postid_7472427588">2012 Nissan Quest SV</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-price">$8,500</span>
#  <span class="result-hood"> (Waldorf)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2022-04-17 13:28" title="Sun 17 Apr 01:28:06 PM">Apr 17</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7472426087" href="https://washingtondc.craigslist.org/nva/cto/d/fairfax-chevy-express-3500-cutaway-box/7472426087.html" id="postid_7472426087">Chevy Express 3500 Cutaway Box Dully</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-price">$5,900</span>
#  <span class="result-hood"> (Fairfax)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2022-04-17 13:27" title="Sun 17 Apr 01:27:25 PM">Apr 17</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7472425842" href="https://washingtondc.craigslist.org/mld/cto/d/silver-spring-2007-toyota-camry/7472425842.html" id="postid_7472425842">2007 Toyota Camry</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-price">$5,500</span>
#  <span class="result-hood"> (Silver Spring)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2022-04-17 13:27" title="Sun 17 Apr 01:27:22 PM">Apr 17</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7472425828" href="https://washingtondc.craigslist.org/nva/cto/d/pasadena-2022-gmc-sierra-1500-at4-new/7472425828.html" id="postid_7472425828">2022 Gmc sierra 1500 AT4  New Resigned</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-price">$76,000</span>
#  <span class="result-hood"> (northern virginia)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2022-04-17 13:16" title="Sun 17 Apr 01:16:39 PM">Apr 17</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7472422035" href="https://washingtondc.craigslist.org/doc/cto/d/washington-2005-land-rover-lr3-hse/7472422035.html" id="postid_7472422035">2005 Land Rover LR3 HSE</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-price">$7,900</span>
#  <span class="result-hood"> (district of columbia)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2022-04-17 13:14" title="Sun 17 Apr 01:14:51 PM">Apr 17</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7472421383" href="https://washingtondc.craigslist.org/nva/ctd/d/2007-toyota-camry-xle-soper-low-miles/7472421383.html" id="postid_7472421383">2007 TOYOTA CAMRY XLE SOPER LOW MILES</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-price">$11,799</span>
#  <span class="result-hood"> (MANASSAS)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="search-legend bottom">
#  <div class="search-view">
#  <span class="buttongroup"><a class="backtotop button" href="#page-top">^ back to top</a></span>
#  </div>
#  <div class="search-sort">
#  <span class="buttongroup"><a class="backtotop button" href="#page-top">^ back to top</a></span>
#  </div>
#  <div class="paginator buttongroup firstpage">
#  <span class="resulttotal">
#  <span class="for-map">
#          showing <span class="displaycountShow">...</span> postings
#          <span class="zoom-out-for-more" style="display: none">
#              -
#              <a href="">
#                  zoom out for all <span class="total">3000</span>
#  </a>
#  </span>
#  </span>
#  </span>
#  <span class="buttons">
#  <a class="button first" href="/search/cta" title="first page">&lt;&lt;</a>
#  <span class="button first" title="first page">&lt;&lt;</span>
#  <a class="button prev" href="/search/cta" title="previous page">&lt; prev</a>
#  <span class="button prev" title="previous page">&lt; prev</span>
#  <span class="button pagenum">
#  <span class="range">
#  <span class="rangeFrom">1</span>
#                  -
#                  <span class="rangeTo">120</span>
#  </span>
#              /
#              <span class="totalcount">3000</span>
#  </span>
#  <a class="button next" href="/search/cta?s=120" title="next page">next &gt; </a>
#  <span class="button next" title="next page"> next &gt; </span>
#  </span>
#  </div>
#  </div>,
#  <div class="search-view">
#  <span class="buttongroup"><a class="backtotop button" href="#page-top">^ back to top</a></span>
#  </div>,
#  <div class="search-sort">
#  <span class="buttongroup"><a class="backtotop button" href="#page-top">^ back to top</a></span>
#  </div>,
#  <div class="paginator buttongroup firstpage">
#  <span class="resulttotal">
#  <span class="for-map">
#          showing <span class="displaycountShow">...</span> postings
#          <span class="zoom-out-for-more" style="display: none">
#              -
#              <a href="">
#                  zoom out for all <span class="total">3000</span>
#  </a>
#  </span>
#  </span>
#  </span>
#  <span class="buttons">
#  <a class="button first" href="/search/cta" title="first page">&lt;&lt;</a>
#  <span class="button first" title="first page">&lt;&lt;</span>
#  <a class="button prev" href="/search/cta" title="previous page">&lt; prev</a>
#  <span class="button prev" title="previous page">&lt; prev</span>
#  <span class="button pagenum">
#  <span class="range">
#  <span class="rangeFrom">1</span>
#                  -
#                  <span class="rangeTo">120</span>
#  </span>
#              /
#              <span class="totalcount">3000</span>
#  </span>
#  <a class="button next" href="/search/cta?s=120" title="next page">next &gt; </a>
#  <span class="button next" title="next page"> next &gt; </span>
#  </span>
#  </div>,
#  <div id="floater">
#  <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif"/>
#  <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif"/>
#  </div>,
#  <div class="slidemessage">
#  <span class="fave">
#  <span class="star"></span>
#          favorited
#      </span>
#  <span class="unfave">
#  <span class="star"></span>
#          no longer favorited
#      </span>
#  <span class="hide">
#  <span class="trash"></span>
#          hidden
#      </span>
#  <span class="unhide">
#  <span class="trash"></span>
#          no longer hidden
#      </span>
#  </div>,
#  <div class="slider-info"></div>,
#  <div class="slider-back arrow">‹</div>,
#  <div class="slider-forward arrow">›</div>]

# %%
#tag with class 

soup.find('div', class_='result-info')
# Out:
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2022-04-18 06:48" title="Mon 18 Apr 06:48:25 AM">Apr 18</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7472628127" href="https://washingtondc.craigslist.org/nva/ctd/d/washington-2016-ford-explorer-xlt-sport/7472628127.html" id="postid_7472628127">2016 Ford Explorer XLT Sport Utility 4D suv Silver - FINANCE ONLINE</a>
# </h3>
# <span class="result-meta">
# <span class="result-price">$29,590</span>
# <span class="result-hood"> (TOUCHLESS DELIVERY TO YOUR HOME)</span>
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>

# %%
car=soup.find('div', class_='result-info')
print(car.h3.get_text(strip=True))
print(car.a.get('href'))
print(car.find('a').get('href'))
print(car.find('a').get('data-id'))
print(car.find(class_='result-price').get_text())
print(car.find(class_='result-hood').get_text(strip=True))
print(car.find(class_='result-date').get('title'))
print(car.find(class_='result-date').get('datetime'))
print(car.find(class_='result-date').get_text())
# Out:
# 2016 Ford Explorer XLT Sport Utility 4D suv Silver - FINANCE ONLINE
# https://washingtondc.craigslist.org/nva/ctd/d/washington-2016-ford-explorer-xlt-sport/7472628127.html
# https://washingtondc.craigslist.org/nva/ctd/d/washington-2016-ford-explorer-xlt-sport/7472628127.html
# 7472628127
# $29,590
# (TOUCHLESS DELIVERY TO YOUR HOME)
# Mon 18 Apr 06:48:25 AM
# 2022-04-18 06:48
# Apr 18

# %% [markdown]
# - `contents` attribute provides all the body of the soup object (generally as a list).
# - `children` attributes provides an iterator to all the tags within the body of the soup object.

# %%
#children
print(car.contents)
for child in car.children:
    print(child)
# Out:
# ['\n', <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>, '\n', <time class="result-date" datetime="2022-04-18 06:48" title="Mon 18 Apr 06:48:25 AM">Apr 18</time>, '\n', <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7472628127" href="https://washingtondc.craigslist.org/nva/ctd/d/washington-2016-ford-explorer-xlt-sport/7472628127.html" id="postid_7472628127">2016 Ford Explorer XLT Sport Utility 4D suv Silver - FINANCE ONLINE</a>
# </h3>, '\n', <span class="result-meta">
# <span class="result-price">$29,590</span>
# <span class="result-hood"> (TOUCHLESS DELIVERY TO YOUR HOME)</span>
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>, '\n']
#
#
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
#
#
# <time class="result-date" datetime="2022-04-18 06:48" title="Mon 18 Apr 06:48:25 AM">Apr 18</time>
#
#
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7472628127" href="https://washingtondc.craigslist.org/nva/ctd/d/washington-2016-ford-explorer-xlt-sport/7472628127.html" id="postid_7472628127">2016 Ford Explorer XLT Sport Utility 4D suv Silver - FINANCE ONLINE</a>
# </h3>
#
#
# <span class="result-meta">
# <span class="result-price">$29,590</span>
# <span class="result-hood"> (TOUCHLESS DELIVERY TO YOUR HOME)</span>
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>

# %% [markdown]
# Let us gather all required data for each car and store it in a dataframe object for later us

# %%
len(soup.find_all('div', class_='result-info'))
# Out:
# 120

# %%
l=[]
for car in soup.find_all('div', class_='result-info'):
    o=[car.a.get('data-id'),car.h3.get_text(strip=True), car.find('span',class_='result-price').text,car.find('span',class_='result-hood').text.replace('(','').replace(')',''),car.find(class_='result-date').get('datetime'),car.a.get('href')]
    l.append(o)

# %%
l
#len(l)
# Out:
# [['7472628127',
#   '2016 Ford Explorer XLT Sport Utility 4D suv Silver - FINANCE ONLINE',
#   '$29,590',
#   ' TOUCHLESS DELIVERY TO YOUR HOME',
#   '2022-04-18 06:48',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2016-ford-explorer-xlt-sport/7472628127.html'],
#  ['7472628110',
#   '2019 BMW i3 Base w/Range Extender Hatchback 4D hatchback Black -',
#   '$35,590',
#   ' TOUCHLESS DELIVERY TO YOUR HOME',
#   '2022-04-18 06:48',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2019-bmw-i3-base-range/7472628110.html'],
#  ['7472628103',
#   '2019 Volvo XC90 T6 Inscription Sport Utility 4D suv Silver - FINANCE',
#   '$55,590',
#   ' TOUCHLESS DELIVERY TO YOUR HOME',
#   '2022-04-18 06:48',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2019-volvo-xc90-t6-in-ion/7472628103.html'],
#  ['7472627916',
#   '2021 Lexus RX RX 350 Sport Utility 4D suv Black - FINANCE ONLINE',
#   '$51,590',
#   ' TOUCHLESS DELIVERY TO YOUR HOME',
#   '2022-04-18 06:46',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2021-lexus-rx-rx-350-sport/7472627916.html'],
#  ['7472627915',
#   '2021 Chevy Chevrolet Silverado 2500 HD Crew Cab LT Pickup 4D 6 1/2 ft',
#   '$65,990',
#   ' TOUCHLESS DELIVERY TO YOUR HOME',
#   '2022-04-18 06:46',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2021-chevy-chevrolet/7472627915.html'],
#  ['7472627913',
#   '2019 BMW Z4 sDrive30i Roadster 2D Convertible Black - FINANCE ONLINE',
#   '$52,590',
#   ' TOUCHLESS DELIVERY TO YOUR HOME',
#   '2022-04-18 06:46',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2019-bmw-z4-sdrive30i/7472627913.html'],
#  ['7472626302',
#   '2017 Caddy Cadillac CT6 2.0 Turbo Sedan 4D sedan Silver - FINANCE',
#   '$30,990',
#   ' TOUCHLESS DELIVERY TO YOUR HOME',
#   '2022-04-18 06:30',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2017-caddy-cadillac-ct6-20/7472626302.html'],
#  ['7472626297',
#   '2021 Honda Pilot Special Edition Sport Utility 4D suv Silver - FINANCE',
#   '$40,590',
#   ' TOUCHLESS DELIVERY TO YOUR HOME',
#   '2022-04-18 06:30',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2021-honda-pilot-special/7472626297.html'],
#  ['7472626293',
#   '2018 MAZDA CX5 Touring Sport Utility 4D suv Blue - FINANCE ONLINE',
#   '$26,590',
#   ' TOUCHLESS DELIVERY TO YOUR HOME',
#   '2022-04-18 06:30',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2018-mazda-cx5-touring-sport/7472626293.html'],
#  ['7472625262',
#   '2018 Honda CRV LX Sport Utility 4D suv Black - FINANCE ONLINE',
#   '$27,590',
#   ' TOUCHLESS DELIVERY TO YOUR HOME',
#   '2022-04-18 06:18',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2018-honda-crv-lx-sport/7472625262.html'],
#  ['7472625259',
#   '2017 Toyota RAV4 XLE Sport Utility 4D suv Burgundy - FINANCE ONLINE',
#   '$26,590',
#   ' TOUCHLESS DELIVERY TO YOUR HOME',
#   '2022-04-18 06:18',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2017-toyota-rav4-xle-sport/7472625259.html'],
#  ['7472625265',
#   '2017 Honda HRV EX Sport Utility 4D suv Red - FINANCE ONLINE',
#   '$23,590',
#   ' TOUCHLESS DELIVERY TO YOUR HOME',
#   '2022-04-18 06:18',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2017-honda-hrv-ex-sport/7472625265.html'],
#  ['7472624317',
#   '2013 Lexus CT CT 200h Hatchback 4D hatchback Black - FINANCE ONLINE',
#   '$20,590',
#   ' TOUCHLESS DELIVERY TO YOUR HOME',
#   '2022-04-18 06:07',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2013-lexus-ct-ct-200h/7472624317.html'],
#  ['7472624311',
#   '2016 Caddy Cadillac CT6 3.6 Premium Luxury Sedan 4D sedan Black -',
#   '$36,990',
#   ' TOUCHLESS DELIVERY TO YOUR HOME',
#   '2022-04-18 06:07',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2016-caddy-cadillac-ct6-36/7472624311.html'],
#  ['7472624289',
#   '2019 Honda CRV LX Sport Utility 4D suv Black - FINANCE ONLINE',
#   '$29,590',
#   ' TOUCHLESS DELIVERY TO YOUR HOME',
#   '2022-04-18 06:06',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2019-honda-crv-lx-sport/7472624289.html'],
#  ['7472622053',
#   '2002 Toyota sequoia',
#   '$2,600',
#   ' northern virginia',
#   '2022-04-18 05:33',
#   'https://washingtondc.craigslist.org/nva/cto/d/springfield-2002-toyota-sequoia/7472622053.html'],
#  ['7472617053',
#   '2009 Hyundai Elantra',
#   '$4,820',
#   ' Alexandria',
#   '2022-04-18 03:54',
#   'https://washingtondc.craigslist.org/nva/cto/d/alexandria-2009-hyundai-elantra/7472617053.html'],
#  ['7472608445',
#   '2004 Mazda3 sedan  $4200 obo',
#   '$4,200',
#   ' CHANTILLY',
#   '2022-04-18 01:42',
#   'https://washingtondc.craigslist.org/nva/cto/d/chantilly-2004-mazda3-sedan-4200-obo/7472608445.html'],
#  ['7472607832',
#   '2009 Mercedes-Benz E350 4Matic - - $5,800 obo',
#   '$5,800',
#   ' Chantilly',
#   '2022-04-18 01:33',
#   'https://washingtondc.craigslist.org/nva/cto/d/chantilly-2009-mercedes-benz-e350/7472607832.html'],
#  ['7472599712',
#   'Clean 2016 Nissan Versa sv for sale',
#   '$6,250',
#   ' Laurel',
#   '2022-04-18 00:17',
#   'https://washingtondc.craigslist.org/mld/cto/d/laurel-clean-2016-nissan-versa-sv-for/7472599712.html'],
#  ['7472597499',
#   '2010 Nissan Maxima',
#   '$2,300',
#   ' Washington DC',
#   '2022-04-18 00:00',
#   'https://washingtondc.craigslist.org/doc/cto/d/washington-2010-nissan-maxima/7472597499.html'],
#  ['7472594926',
#   '1992 Peterbilt',
#   '$25,000',
#   ' northern virginia',
#   '2022-04-17 23:42',
#   'https://washingtondc.craigslist.org/nva/cto/d/woodbridge-1992-peterbilt/7472594926.html'],
#  ['7472589864',
#   '2000 manual Honda CRV',
#   '$1,200',
#   ' College Park',
#   '2022-04-17 23:10',
#   'https://washingtondc.craigslist.org/mld/cto/d/college-park-2000-manual-honda-crv/7472589864.html'],
#  ['7472589071',
#   '2004 Ford F-150',
#   '$1,000',
#   ' northern virginia',
#   '2022-04-17 23:05',
#   'https://washingtondc.craigslist.org/nva/cto/d/manassas-2004-ford-150/7472589071.html'],
#  ['7472588632',
#   '2001 Chevrolet van',
#   '$2,500',
#   ' northern virginia',
#   '2022-04-17 23:02',
#   'https://washingtondc.craigslist.org/nva/cto/d/manassas-2001-chevrolet-van/7472588632.html'],
#  ['7472582469',
#   '2001 HONDA CIVIC 2D EX',
#   '$3,900',
#   ' Arlington VA',
#   '2022-04-17 22:27',
#   'https://washingtondc.craigslist.org/nva/cto/d/arlington-2001-honda-civic-2d-ex/7472582469.html'],
#  ['7472579147',
#   '2016 Freightliner Cascadia 125, DD15 475HP, 10 speed Manual Transmis',
#   '$49,500',
#   ' Sterling VA',
#   '2022-04-17 22:10',
#   'https://washingtondc.craigslist.org/nva/cto/d/sterling-2016-freightliner-cascadia-125/7472579147.html'],
#  ['7472579118',
#   '2007 Nissan Altima',
#   '$2,700',
#   ' Manassas',
#   '2022-04-17 22:10',
#   'https://washingtondc.craigslist.org/nva/cto/d/manassas-2007-nissan-altima/7472579118.html'],
#  ['7472574582',
#   '2005 Toyota Sequoia 4WD Limited, 140K miles',
#   '$14,500',
#   ' northern virginia',
#   '2022-04-17 21:48',
#   'https://washingtondc.craigslist.org/nva/cto/d/chantilly-2005-toyota-sequoia-4wd/7472574582.html'],
#  ['7472574339',
#   'Toyota Tacoma 2009',
#   '$4,650',
#   ' Hyattsville',
#   '2022-04-17 21:47',
#   'https://washingtondc.craigslist.org/doc/cto/d/hyattsville-toyota-tacoma-2009/7472574339.html'],
#  ['7472570452',
#   '2004 Honda Accord 4 dr - 90k Miles - Single-Family Ownership',
#   '$6,500',
#   ' Fairfax',
#   '2022-04-17 21:30',
#   'https://washingtondc.craigslist.org/nva/cto/d/fairfax-2004-honda-accord-dr-90k-miles/7472570452.html'],
#  ['7472562458',
#   '2000 Toyota Land Cruiser V8 4.7L Automatic 4x4 GREAT CONDITION & PRICE',
#   '$15,900',
#   ' ROYAL PIKE MOTORS',
#   '2022-04-17 20:55',
#   'https://washingtondc.craigslist.org/doc/ctd/d/arlington-2000-toyota-land-cruiser-v8/7472562458.html'],
#  ['7472560810',
#   '2001 lexus es 300',
#   '$2,500',
#   ' Burtonsville',
#   '2022-04-17 20:47',
#   'https://washingtondc.craigslist.org/mld/cto/d/burtonsville-2001-lexus-es-300/7472560810.html'],
#  ['7472553646',
#   'Toyota 4 runner',
#   '$4,700',
#   ' maryland',
#   '2022-04-17 20:17',
#   'https://washingtondc.craigslist.org/mld/ctd/d/rockville-toyota-runner/7472553646.html'],
#  ['7472552352',
#   'Toyota highlander',
#   '$12,500',
#   ' Manassas',
#   '2022-04-17 20:12',
#   'https://washingtondc.craigslist.org/nva/cto/d/manassas-toyota-highlander/7472552352.html'],
#  ['7472552078',
#   'Mazda 3',
#   '$4,700',
#   ' maryland',
#   '2022-04-17 20:11',
#   'https://washingtondc.craigslist.org/mld/ctd/d/rockville-mazda/7472552078.html'],
#  ['7472548804',
#   'Nissan Armada',
#   '$5,500',
#   ' Woodbridge VA',
#   '2022-04-17 19:58',
#   'https://washingtondc.craigslist.org/nva/cto/d/woodbridge-nissan-armada/7472548804.html'],
#  ['7472545809',
#   '2000 Toyota Camry',
#   '$8,000',
#   ' Gaithersburg',
#   '2022-04-17 19:46',
#   'https://washingtondc.craigslist.org/doc/cto/d/gaithersburg-2000-toyota-camry/7472545809.html'],
#  ['7472542447',
#   '2006 Chevy Suburban Z71',
#   '$7,000',
#   ' Rockville',
#   '2022-04-17 19:33',
#   'https://washingtondc.craigslist.org/mld/cto/d/rockville-2006-chevy-suburban-z71/7472542447.html'],
#  ['7472540115',
#   'Black Lexus(Flooded)',
#   '$1,750',
#   ' Lanham',
#   '2022-04-17 19:24',
#   'https://washingtondc.craigslist.org/mld/cto/d/lanham-black-lexusflooded/7472540115.html'],
#  ['7472539373',
#   'Lincoln',
#   '$1,800',
#   ' Woodbridge',
#   '2022-04-17 19:22',
#   'https://washingtondc.craigslist.org/doc/cto/d/woodbridge-lincoln/7472539373.html'],
#  ['7472539203',
#   '2012 BMW 335i E93 Convertible - Super Clean',
#   '$16,500',
#   ' rockville',
#   '2022-04-17 19:21',
#   'https://washingtondc.craigslist.org/mld/cto/d/suburb-maryland-fac-2012-bmw-335i-e93/7472539203.html'],
#  ['7472538398',
#   '2012 Ford Transit Connect XL Cargo Van',
#   '$17,500',
#   ' Arlington',
#   '2022-04-17 19:18',
#   'https://washingtondc.craigslist.org/nva/cto/d/arlington-2012-ford-transit-connect-xl/7472538398.html'],
#  ['7472536978',
#   '1987 Chryler Conquest TSi / Starion',
#   '$3,000',
#   ' Bealeton VA',
#   '2022-04-17 19:13',
#   'https://washingtondc.craigslist.org/nva/cto/d/warrenton-1987-chryler-conquest-tsi/7472536978.html'],
#  ['7472534538',
#   'Honda CRV LX for sale',
#   '$14,000',
#   ' Burke/springfield',
#   '2022-04-17 19:03',
#   'https://washingtondc.craigslist.org/nva/cto/d/springfield-honda-crv-lx-for-sale/7472534538.html'],
#  ['7472534378',
#   '2014 HYUNDAI VELOSTER Turbo APPROVED!!! APPROVED!!! APPROVED!!!',
#   '$11,995',
#   ' + DMV Auto Finance',
#   '2022-04-17 19:03',
#   'https://washingtondc.craigslist.org/doc/ctd/d/fredericksburg-2014-hyundai-veloster/7472534378.html'],
#  ['7472534322',
#   '2014 HYUNDAI VELOSTER Turbo APPROVED!!! APPROVED!!! APPROVED!!!',
#   '$11,995',
#   ' + DMV Auto Finance',
#   '2022-04-17 19:03',
#   'https://washingtondc.craigslist.org/mld/ctd/d/fredericksburg-2014-hyundai-veloster/7472534322.html'],
#  ['7472534251',
#   '2014 HYUNDAI VELOSTER Turbo APPROVED!!! APPROVED!!! APPROVED!!!',
#   '$11,995',
#   ' + DMV Auto Finance',
#   '2022-04-17 19:02',
#   'https://washingtondc.craigslist.org/nva/ctd/d/fredericksburg-2014-hyundai-veloster/7472534251.html'],
#  ['7472533294',
#   '2008 Jeep Patriot',
#   '$6,000',
#   ' Springfield VA',
#   '2022-04-17 19:00',
#   'https://washingtondc.craigslist.org/nva/cto/d/springfield-2008-jeep-patriot/7472533294.html'],
#  ['7472529820',
#   '2013 Honda accord in excellent condition',
#   '$11,500',
#   ' Chantilly',
#   '2022-04-17 18:47',
#   'https://washingtondc.craigslist.org/nva/cto/d/chantilly-2013-honda-accord-in/7472529820.html'],
#  ['7472527901',
#   '2007 Acura TSX',
#   '$6,800',
#   ' northern virginia',
#   '2022-04-17 18:40',
#   'https://washingtondc.craigslist.org/nva/cto/d/manassas-2007-acura-tsx/7472527901.html'],
#  ['7472527525',
#   '1999 Mack CL700',
#   '$59,900',
#   ' Sterling',
#   '2022-04-17 18:39',
#   'https://washingtondc.craigslist.org/doc/cto/d/herndon-1999-mack-cl700/7472527525.html'],
#  ['7472519874',
#   'Mercedes clk550 convertible 2007',
#   '$7,500',
#   ' Washington',
#   '2022-04-17 18:11',
#   'https://washingtondc.craigslist.org/doc/cto/d/washington-mercedes-clk550-convertible/7472519874.html'],
#  ['7472518740',
#   '2009 Chevrolet Cobalt (Low Mileage)',
#   '$5,000',
#   ' Washington, DC',
#   '2022-04-17 18:07',
#   'https://washingtondc.craigslist.org/doc/cto/d/washington-2009-chevrolet-cobalt-low/7472518740.html'],
#  ['7472516461',
#   'Honda Accord 2013',
#   '$13,500',
#   ' Sterling',
#   '2022-04-17 17:59',
#   'https://washingtondc.craigslist.org/nva/cto/d/sterling-honda-accord-2013/7472516461.html'],
#  ['7472514856',
#   '2007 Chevrolet Equinox',
#   '$4,500',
#   ' Brandywine',
#   '2022-04-17 17:53',
#   'https://washingtondc.craigslist.org/mld/cto/d/brandywine-2007-chevrolet-equinox/7472514856.html'],
#  ['7472511824',
#   'Food Truck 2015 GMC 3500 HD',
#   '$30,000',
#   ' Upper Marlboro',
#   '2022-04-17 17:43',
#   'https://washingtondc.craigslist.org/mld/cto/d/upper-marlboro-food-truck-2015-gmc-3500/7472511824.html'],
#  ['7472510805',
#   '95 Ford Econoline 350',
#   '$5,200',
#   ' One Loudoun',
#   '2022-04-17 17:40',
#   'https://washingtondc.craigslist.org/nva/cto/d/ashburn-95-ford-econoline-350/7472510805.html'],
#  ['7472507801',
#   '2004 Toyota Landcruiser',
#   '$12,000',
#   ' district of columbia',
#   '2022-04-17 17:30',
#   'https://washingtondc.craigslist.org/doc/cto/d/laurel-2004-toyota-landcruiser/7472507801.html'],
#  ['7472503846',
#   '2016 CHRYSLER 300 S -WE FINANCE EVERYONE! CALL NOW!!!',
#   '$0',
#   ' + Kargar Motors Of Manassas',
#   '2022-04-17 17:17',
#   'https://washingtondc.craigslist.org/nva/ctd/d/manassas-2016-chrysler-300-we-finance/7472503846.html'],
#  ['7472503174',
#   '2005 CHEVROLET CORVETTE',
#   '$26,500',
#   ' 2005 CHEVROLET CORVETTE',
#   '2022-04-17 17:15',
#   'https://washingtondc.craigslist.org/nva/ctd/d/garrisonville-2005-chevrolet-corvette/7472503174.html'],
#  ['7472501175',
#   '2020 BMW X5 xDrive40i Sport Utility 4D SUV',
#   '$75,800',
#   ' ASHBURN, VA',
#   '2022-04-17 17:09',
#   'https://washingtondc.craigslist.org/nva/cto/d/ashburn-2020-bmw-x5-xdrive40i-sport/7472501175.html'],
#  ['7472500025',
#   '2008 KIA RONDO EX LOW MILES',
#   '$5,999',
#   ' MANASSAS',
#   '2022-04-17 17:05',
#   'https://washingtondc.craigslist.org/nva/ctd/d/2008-kia-rondo-ex-low-miles/7472500025.html'],
#  ['7472498265',
#   '2018 KIA SOUL PLUS LOW MILES',
#   '$19,999',
#   ' MANASSAS',
#   '2022-04-17 17:00',
#   'https://washingtondc.craigslist.org/nva/ctd/d/2018-kia-soul-plus-low-miles/7472498265.html'],
#  ['7472496828',
#   '2010 honda accord v6',
#   '$2,500',
#   ' Laurel',
#   '2022-04-17 16:55',
#   'https://washingtondc.craigslist.org/mld/cto/d/laurel-2010-honda-accord-v6/7472496828.html'],
#  ['7472495632',
#   'F-350 stake body 7.3',
#   '$15,000',
#   ' district of columbia',
#   '2022-04-17 16:51',
#   'https://washingtondc.craigslist.org/doc/cto/d/laurel-350-stake-body-73/7472495632.html'],
#  ['7472494656',
#   '* *2005 Lexus GX470 Low Miles Excellent Condition 7 Passenger',
#   '$16,970',
#   ' Rockville, MD',
#   '2022-04-17 16:48',
#   'https://washingtondc.craigslist.org/mld/cto/d/rockville-lexus-gx470-low-miles/7472494656.html'],
#  ['7472494361',
#   '2013 Ford Transit Connect XLT',
#   '$12,000',
#   ' Washington',
#   '2022-04-17 16:47',
#   'https://washingtondc.craigslist.org/doc/cto/d/washington-2013-ford-transit-connect-xlt/7472494361.html'],
#  ['7472491288',
#   'Honda Civic 2005 EX Special Edition – 124K miles',
#   '$5,999',
#   ' Fort Belvoir',
#   '2022-04-17 16:38',
#   'https://washingtondc.craigslist.org/nva/cto/d/fort-belvoir-honda-civic-2005-ex/7472491288.html'],
#  ['7472490020',
#   '2012 Volkswagen Tiguan  SE 4Motion AWD 4dr SUV w/ Sunroof and Navigati',
#   '$12,999',
#   ' CHANTILLY',
#   '2022-04-17 16:34',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2012-volkswagen-tiguan-se/7472490020.html'],
#  ['7472488794',
#   '*2014* *Ford* *Mustang* *CONVERTIBLE 2-DR*',
#   '$13,995',
#   ' _Ford_ _Mustang_ _Coupe_',
#   '2022-04-17 16:30',
#   'https://washingtondc.craigslist.org/nva/ctd/d/garrisonville-2014-ford-mustang/7472488794.html'],
#  ['7472487799',
#   '2019 RAM PROMASTER CARGO VAN 2500 HIGHROOF -WE FINANCE EVERYONE! CALL NOW!!!',
#   '$0',
#   ' + Kargar Motors Of Manassas',
#   '2022-04-17 16:27',
#   'https://washingtondc.craigslist.org/nva/ctd/d/manassas-2019-ram-promaster-cargo-van/7472487799.html'],
#  ['7472486448',
#   '2010 AUDI Q7 TDI PREMIUM PLUS AWD DIESEL 3RD ROW SEAT',
#   '$11,799',
#   ' MANASSAS',
#   '2022-04-17 16:23',
#   'https://washingtondc.craigslist.org/nva/ctd/d/2010-audi-q7-tdi-premium-plus-awd/7472486448.html'],
#  ['7472485302',
#   '2012 Mazda 3 iSport',
#   '$10,200',
#   ' Reston, VA',
#   '2022-04-17 16:19',
#   'https://washingtondc.craigslist.org/nva/cto/d/reston-2012-mazda-isport/7472485302.html'],
#  ['7472485134',
#   '2007 Honda Odyssey EX',
#   '$5,100',
#   ' Herndon',
#   '2022-04-17 16:19',
#   'https://washingtondc.craigslist.org/nva/cto/d/herndon-2007-honda-odyssey-ex/7472485134.html'],
#  ['7472484479',
#   '2009 ACURA MDX TECHNOLOGY AWD 3RD ROW SEATS',
#   '$11,999',
#   ' MANASSAS',
#   '2022-04-17 16:17',
#   'https://washingtondc.craigslist.org/nva/ctd/d/2009-acura-mdx-technology-awd-3rd-row/7472484479.html'],
#  ['7472481135',
#   '2007 Chevy Blazer',
#   '$4,900',
#   ' Lanham Maryland',
#   '2022-04-17 16:07',
#   'https://washingtondc.craigslist.org/mld/cto/d/hyattsville-2007-chevy-blazer/7472481135.html'],
#  ['7472479506',
#   '2017 Ford F-150 F150 F 150 XLT ****We Finance! ****',
#   '$36,999',
#   ' + Premier Automotive',
#   '2022-04-17 16:02',
#   'https://washingtondc.craigslist.org/nva/ctd/d/dumfries-2017-ford-150-f150-150-xlt-we/7472479506.html'],
#  ['7472477571',
#   'BMW 745',
#   '$2,550',
#   ' Lanham MD',
#   '2022-04-17 15:57',
#   'https://washingtondc.craigslist.org/mld/cto/d/bowie-bmw-745/7472477571.html'],
#  ['7472476364',
#   '2011 BMW 3 Series 328i convertible',
#   '$14,000',
#   ' McLean',
#   '2022-04-17 15:53',
#   'https://washingtondc.craigslist.org/nva/cto/d/mc-lean-2011-bmw-series-328i-convertible/7472476364.html'],
#  ['7472473708',
#   '2010 MAZDA 3 iTouring',
#   '$6,400',
#   ' 2010 MAZDA 3 iTouring',
#   '2022-04-17 15:45',
#   'https://washingtondc.craigslist.org/nva/ctd/d/garrisonville-2010-mazda-itouring/7472473708.html'],
#  ['7472471095',
#   '2015 LEXUS RC 350 GSC10L/GSC15L/ASC10L/GSC16L -WE FINANCE EVERYONE! CALL NOW!!!',
#   '$0',
#   ' + Kargar Motors Of Manassas',
#   '2022-04-17 15:37',
#   'https://washingtondc.craigslist.org/nva/ctd/d/manassas-2015-lexus-rc-350-gsc10l/7472471095.html'],
#  ['7472469064',
#   '2015 GMC Terrain SLT-1 Sport Utility 4D',
#   '$19,115',
#   ' _GMC_ _Terrain_ _SUV_',
#   '2022-04-17 15:31',
#   'https://washingtondc.craigslist.org/doc/ctd/d/garrisonville-2015-gmc-terrain-slt/7472469064.html'],
#  ['7472469007',
#   '2013 BMW 535i xDrive Gran Turismo 535i Gran Turismo xDrive Sedan 4D',
#   '$17,480',
#   ' _BMW_ _535i xDrive Gran Turismo_ _Sedan_',
#   '2022-04-17 15:31',
#   'https://washingtondc.craigslist.org/doc/ctd/d/garrisonville-2013-bmw-535i-xdrive-gran/7472469007.html'],
#  ['7472467932',
#   '2015 Honda Civic Runs And Drives Good Clean Title 155,000 Miles Priced To Sell',
#   '$8,300',
#   ' Gaithersburg',
#   '2022-04-17 15:27',
#   'https://washingtondc.craigslist.org/doc/cto/d/germantown-2015-honda-civic-runs-and/7472467932.html'],
#  ['7472467565',
#   '2008 TOYOTA RAV4 LIMITED ONE OWNER',
#   '$10,799',
#   ' MANASSAS',
#   '2022-04-17 15:26',
#   'https://washingtondc.craigslist.org/nva/ctd/d/2008-toyota-rav4-limited-one-owner/7472467565.html'],
#  ['7472466285',
#   '2018 KIA SOUL ! 6 MONTHS WARRANTY INCLUDED',
#   '$16,438',
#   ' + Beyond Motors LLC',
#   '2022-04-17 15:22',
#   'https://washingtondc.craigslist.org/nva/ctd/d/manassas-2018-kia-soul-months-warranty/7472466285.html'],
#  ['7472465609',
#   '2009 Toyota HIGHLANDER HYBRID LIMITED AWD 3RD ROW SEATS',
#   '$12,999',
#   ' MANASSAS',
#   '2022-04-17 15:20',
#   'https://washingtondc.craigslist.org/nva/ctd/d/2009-toyota-highlander-hybrid-limited/7472465609.html'],
#  ['7472465166',
#   '2008 TOYOTA HIGHLANDER LIMITED AWD 3RD ROW SEATS',
#   '$10,999',
#   ' MANASSAS',
#   '2022-04-17 15:19',
#   'https://washingtondc.craigslist.org/nva/ctd/d/2008-toyota-highlander-limited-awd-3rd/7472465166.html'],
#  ['7472464536',
#   '2007 VOLKSWAGEN NEW BEETLE 2.5L SUPER LOW MILES',
#   '$9,999',
#   ' MANASSAS',
#   '2022-04-17 15:17',
#   'https://washingtondc.craigslist.org/nva/ctd/d/2007-volkswagen-new-beetle-25l-super/7472464536.html'],
#  ['7472462993',
#   '2011 Mazda 3 (Sped 5 Stick shift!)',
#   '$6,500',
#   ' Bowie',
#   '2022-04-17 15:12',
#   'https://washingtondc.craigslist.org/mld/cto/d/bowie-2011-mazda-sped-stick-shift/7472462993.html'],
#  ['7472454631',
#   '2018 Audi S5 Prestige',
#   '$45,500',
#   ' Hagerstown',
#   '2022-04-17 14:49',
#   'https://washingtondc.craigslist.org/mld/cto/d/hagerstown-2018-audi-s5-prestige/7472454631.html'],
#  ['7472454057',
#   '2018 JEEP COMPASS Sport -WE FINANCE EVERYONE! CALL NOW!!!',
#   '$0',
#   ' + Kargar Motors Of Manassas',
#   '2022-04-17 14:47',
#   'https://washingtondc.craigslist.org/nva/ctd/d/manassas-2018-jeep-compass-sport-we/7472454057.html'],
#  ['7472451327',
#   '2008 Mini Cooper S',
#   '$6,500',
#   ' Alexandria',
#   '2022-04-17 14:39',
#   'https://washingtondc.craigslist.org/doc/cto/d/alexandria-2008-mini-cooper/7472451327.html'],
#  ['7472450327',
#   '2008 Acura TL Type-S 221k Miles',
#   '$3,500',
#   ' Old Town Alexandria',
#   '2022-04-17 14:36',
#   'https://washingtondc.craigslist.org/nva/cto/d/alexandria-2008-acura-tl-type-221k-miles/7472450327.html'],
#  ['7472445382',
#   '2012 Volkswagen Jetta SE PZEV 4dr Sedan 6A w/ Convenience',
#   '$7,999',
#   ' CHANTILLY',
#   '2022-04-17 14:22',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2012-volkswagen-jetta-se/7472445382.html'],
#  ['7472444644',
#   '2018 *Lexus* *RX* *RX 350 AWD* Nightfall Mica',
#   '$40,995',
#   ' Elite Auto Brokers',
#   '2022-04-17 14:20',
#   'https://washingtondc.craigslist.org/mld/ctd/d/gaithersburg-2018-lexus-rx-rx-350-awd/7472444644.html'],
#  ['7472444587',
#   '2020 *Porsche* *911* *Carrera S Coupe* Night Blue Me',
#   '$123,500',
#   ' Elite Auto Brokers',
#   '2022-04-17 14:20',
#   'https://washingtondc.craigslist.org/mld/ctd/d/gaithersburg-2020-porsche-911-carrera/7472444587.html'],
#  ['7472443306',
#   '2014 Volkswagen Jetta SE PZEV 4dr Sedan 6A',
#   '$9,499',
#   ' CHANTILLY',
#   '2022-04-17 14:16',
#   'https://washingtondc.craigslist.org/nva/ctd/d/washington-2014-volkswagen-jetta-se/7472443306.html'],
#  ['7472440767',
#   '2006 Volvo S60 2.5T',
#   '$4,990',
#   ' Oakton',
#   '2022-04-17 14:09',
#   'https://washingtondc.craigslist.org/nva/cto/d/oakton-2006-volvo-s60-25t/7472440767.html'],
#  ['7472440330',
#   '2010 Nissan Altima, Low Miles, One Owner, No Accident, Drive Like New.',
#   '$5,980',
#   ' Germantown',
#   '2022-04-17 14:08',
#   'https://washingtondc.craigslist.org/mld/cto/d/germantown-2010-nissan-altima-low-miles/7472440330.html'],
#  ['7472439980',
#   '2011 Toyota Prius - Single Owner',
#   '$19,500',
#   ' Herndon/Reston/Great Falls',
#   '2022-04-17 14:07',
#   'https://washingtondc.craigslist.org/nva/cto/d/herndon-2011-toyota-prius-single-owner/7472439980.html'],
#  ['7472439716',
#   '2008 BMW X5',
#   '$7,750',
#   ' Harpers Ferry/Ashburn',
#   '2022-04-17 14:06',
#   'https://washingtondc.craigslist.org/nva/cto/d/halltown-2008-bmw-x5/7472439716.html'],
#  ['7472438294',
#   '2019 Mitsubishi Outlander Sport 2.0 ****We Finance! ****',
#   '$20,450',
#   ' + Premier Automotive',
#   '2022-04-17 14:02',
#   'https://washingtondc.craigslist.org/nva/ctd/d/dumfries-2019-mitsubishi-outlander/7472438294.html'],
#  ['7472436359',
#   '2019 TOYOTA CAMRY LE -WE FINANCE EVERYONE! CALL NOW!!!',
#   '$0',
#   ' + Kargar Motors Of Manassas',
#   '2022-04-17 13:57',
#   'https://washingtondc.craigslist.org/nva/ctd/d/manassas-2019-toyota-camry-le-we/7472436359.html'],
#  ['7472434351',
#   '2002 Toyota Corolla S - Low Miles',
#   '$3,025',
#   ' district of columbia',
#   '2022-04-17 13:51',
#   'https://washingtondc.craigslist.org/doc/cto/d/washington-2002-toyota-corolla-low-miles/7472434351.html'],
#  ['7472434030',
#   '2009 Ford Fusion',
#   '$2,500',
#   ' North Potomac',
#   '2022-04-17 13:51',
#   'https://washingtondc.craigslist.org/mld/cto/d/gaithersburg-2009-ford-fusion/7472434030.html'],
#  ['7472432626',
#   '2012 nissan maxima sport',
#   '$13,500',
#   ' Centreville',
#   '2022-04-17 13:47',
#   'https://washingtondc.craigslist.org/nva/cto/d/centreville-2012-nissan-maxima-sport/7472432626.html'],
#  ['7472432411',
#   'Toyota Camry 2016 SE',
#   '$16,500',
#   ' Manassas',
#   '2022-04-17 13:46',
#   'https://washingtondc.craigslist.org/nva/cto/d/manassas-toyota-camry-2016-se/7472432411.html'],
#  ['7472432086',
#   '2004 FORD EXPLORER SPORT',
#   '$7,400',
#   ' 2004 FORD EXPLORER SPORT',
#   '2022-04-17 13:45',
#   'https://washingtondc.craigslist.org/nva/ctd/d/garrisonville-2004-ford-explorer-sport/7472432086.html'],
#  ['7472431689',
#   'Toyota Avalon 4 Sale',
#   '$4,250',
#   ' gaithersburg',
#   '2022-04-17 13:44',
#   'https://washingtondc.craigslist.org/mld/cto/d/gaithersburg-toyota-avalon-sale/7472431689.html'],
#  ['7472431688',
#   '2015 BMW x3 xDrive35i Sport Utility 4D',
#   '$13,500',
#   ' Reston',
#   '2022-04-17 13:44',
#   'https://washingtondc.craigslist.org/nva/cto/d/reston-2015-bmw-x3-xdrive35i-sport/7472431688.html'],
#  ['7472431196',
#   '2012 GMC ACADIA DENALI 6 MONTHS WARRANTY INCLUDED',
#   '$15,983',
#   ' + Beyond Motors LLC',
#   '2022-04-17 13:42',
#   'https://washingtondc.craigslist.org/nva/ctd/d/manassas-2012-gmc-acadia-denali-months/7472431196.html'],
#  ['7472430011',
#   'Kia Niro LX Hybrid',
#   '$16,800',
#   ' Centreville',
#   '2022-04-17 13:39',
#   'https://washingtondc.craigslist.org/nva/cto/d/centreville-kia-niro-lx-hybrid/7472430011.html'],
#  ['7472427588',
#   '2012 Nissan Quest SV',
#   '$8,500',
#   ' Waldorf',
#   '2022-04-17 13:32',
#   'https://washingtondc.craigslist.org/mld/cto/d/waldorf-2012-nissan-quest-sv/7472427588.html'],
#  ['7472426087',
#   'Chevy Express 3500 Cutaway Box Dully',
#   '$5,900',
#   ' Fairfax',
#   '2022-04-17 13:28',
#   'https://washingtondc.craigslist.org/nva/cto/d/fairfax-chevy-express-3500-cutaway-box/7472426087.html'],
#  ['7472425842',
#   '2007 Toyota Camry',
#   '$5,500',
#   ' Silver Spring',
#   '2022-04-17 13:27',
#   'https://washingtondc.craigslist.org/mld/cto/d/silver-spring-2007-toyota-camry/7472425842.html'],
#  ['7472425828',
#   '2022 Gmc sierra 1500 AT4  New Resigned',
#   '$76,000',
#   ' northern virginia',
#   '2022-04-17 13:27',
#   'https://washingtondc.craigslist.org/nva/cto/d/pasadena-2022-gmc-sierra-1500-at4-new/7472425828.html'],
#  ['7472422035',
#   '2005 Land Rover LR3 HSE',
#   '$7,900',
#   ' district of columbia',
#   '2022-04-17 13:16',
#   'https://washingtondc.craigslist.org/doc/cto/d/washington-2005-land-rover-lr3-hse/7472422035.html'],
#  ['7472421383',
#   '2007 TOYOTA CAMRY XLE SOPER LOW MILES',
#   '$11,799',
#   ' MANASSAS',
#   '2022-04-17 13:14',
#   'https://washingtondc.craigslist.org/nva/ctd/d/2007-toyota-camry-xle-soper-low-miles/7472421383.html']]

# %% [markdown]
# Storing it into dataframe.

# %%
import pandas as pd

df = pd.DataFrame(l,columns=['ID','Name','Price','Area','Date','Link'])

# %%
display(df)
# Out:
#              ID                                               Name    Price  \
# 0    7472628127  2016 Ford Explorer XLT Sport Utility 4D suv Si...  $29,590
# 1    7472628110  2019 BMW i3 Base w/Range Extender Hatchback 4D...  $35,590
# 2    7472628103  2019 Volvo XC90 T6 Inscription Sport Utility 4...  $55,590
# 3    7472627916  2021 Lexus RX RX 350 Sport Utility 4D suv Blac...  $51,590
# 4    7472627915  2021 Chevy Chevrolet Silverado 2500 HD Crew Ca...  $65,990
# ..          ...                                                ...      ...
# 115  7472426087               Chevy Express 3500 Cutaway Box Dully   $5,900
# 116  7472425842                                  2007 Toyota Camry   $5,500
# 117  7472425828             2022 Gmc sierra 1500 AT4  New Resigned  $76,000
# 118  7472422035                            2005 Land Rover LR3 HSE   $7,900
# 119  7472421383              2007 TOYOTA CAMRY XLE SOPER LOW MILES  $11,799
#
#                                  Area              Date  \
# 0     TOUCHLESS DELIVERY TO YOUR HOME  2022-04-18 06:48
# 1     TOUCHLESS DELIVERY TO YOUR HOME  2022-04-18 06:48
# 2     TOUCHLESS DELIVERY TO YOUR HOME  2022-04-18 06:48
# 3     TOUCHLESS DELIVERY TO YOUR HOME  2022-04-18 06:46
# 4     TOUCHLESS DELIVERY TO YOUR HOME  2022-04-18 06:46
# ..                                ...               ...
# 115                           Fairfax  2022-04-17 13:28
# 116                     Silver Spring  2022-04-17 13:27
# 117                 northern virginia  2022-04-17 13:27
# 118              district of columbia  2022-04-17 13:16
# 119                          MANASSAS  2022-04-17 13:14
#
#                                                   Link
# 0    https://washingtondc.craigslist.org/nva/ctd/d/...
# 1    https://washingtondc.craigslist.org/nva/ctd/d/...
# 2    https://washingtondc.craigslist.org/nva/ctd/d/...
# 3    https://washingtondc.craigslist.org/nva/ctd/d/...
# 4    https://washingtondc.craigslist.org/nva/ctd/d/...
# ..                                                 ...
# 115  https://washingtondc.craigslist.org/nva/cto/d/...
# 116  https://washingtondc.craigslist.org/mld/cto/d/...
# 117  https://washingtondc.craigslist.org/nva/cto/d/...
# 118  https://washingtondc.craigslist.org/doc/cto/d/...
# 119  https://washingtondc.craigslist.org/nva/ctd/d/...
#
# [120 rows x 6 columns]

# %%
df.describe()
# Out:
#                 ID                                               Name Price  \
# count          120                                                120   120
# unique         120                                                118    97
# top     7472628127  2014 HYUNDAI VELOSTER Turbo APPROVED!!! APPROV...    $0
# freq             1                                                  3     5
#
#                                     Area              Date  \
# count                                120               120
# unique                                66               102
# top      TOUCHLESS DELIVERY TO YOUR HOME  2022-04-18 06:48
# freq                                  15                 3
#
#                                                      Link
# count                                                 120
# unique                                                120
# top     https://washingtondc.craigslist.org/nva/ctd/d/...
# freq                                                    1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      120 non-null    object
#  1   Name    120 non-null    object
#  2   Price   120 non-null    object
#  3   Area    120 non-null    object
#  4   Date    120 non-null    object
#  5   Link    120 non-null    object
# dtypes: object(6)
# memory usage: 5.8+ KB

# %%
df.to_csv('DataDC.csv')
